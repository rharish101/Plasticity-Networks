# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
from load_pvoc_data import load_data, TRAIN_LENGTH

# %%
BATCH_SIZE = 32
EPOCHS = 4
VALIDATION_SPLIT = 0.3

# %%
def preprocessing(img, lbl):
    crop_img = tf.image.central_crop(img, 1)
    resized = tf.image.resize_images(img, (256, 256))
    norm_img = tf.image.per_image_standardization(resized)
    
    one_hot = tf.one_hot(lbl, 20)
    summed = tf.reduce_sum(one_hot, axis=-2)
    multi_hot = tf.where(
        tf.equal(summed, 0), tf.zeros_like(summed, dtype=tf.float32), tf.ones_like(summed, dtype=tf.float32)
    )
    return norm_img, multi_hot

# %%
def train_input_fn():
    train_dataset = tf.data.Dataset.from_generator(
        lambda:load_data("train"),
        (tf.uint8, tf.int32),
        (tf.TensorShape([None, None, 3]), tf.TensorShape([None]))
    ).map(preprocessing).shuffle(10000)
    train_dataset = train_dataset.apply(tf.contrib.data.assert_element_shape((
        [256, 256, 3],
        [20]
    )))
    
    val_length = int(VALIDATION_SPLIT * TRAIN_LENGTH)
    val_dataset = train_dataset.take(val_length).apply(
        tf.contrib.data.batch_and_drop_remainder(BATCH_SIZE))
    train_dataset = train_dataset.skip(val_length).apply(
        tf.contrib.data.batch_and_drop_remainder(BATCH_SIZE)).repeat()

    return train_dataset, val_dataset

# %%
def test_input_fn():
    test_dataset = tf.data.Dataset.from_generator(
        lambda:load_data("test"),
        (tf.uint8, tf.int32),
        (tf.TensorShape([None, None, 3]), tf.TensorShape([None]))
    )
    test_dataset = test_dataset.map(preprocessing).apply(tf.contrib.data.assert_element_shape((
        [256, 256, 3],
        [20]
    )))
    return test_dataset.apply(tf.contrib.data.batch_and_drop_remainder(BATCH_SIZE))

# %%
def conv_layer(inputs, scope_name, eta=None, filters=32, kernel_size=3, strides=1):
    with tf.variable_scope(scope_name):
        w = tf.get_variable('conv_w', (kernel_size, kernel_size, int(inputs.shape[-1]), filters))
        b = tf.get_variable('conv_b', (filters,))
        if eta is not None:
            alpha = tf.get_variable('conv_alpha', (kernel_size, kernel_size, int(inputs.shape[-1]), filters))
            hebb = tf.get_variable('conv_hebb', (kernel_size, kernel_size, int(inputs.shape[-1]), filters),
                                   trainable=False, initializer=tf.zeros_initializer)
            w = w + tf.multiply(alpha, hebb)
    
    x = tf.nn.conv2d(input=inputs, filter=w, strides=[1, strides, strides, 1], padding='SAME') + b
    
    if eta is not None:
        # y is to be the output reshaped so as to be used as a kernel for convolution on input to get Hebbian update
        y = tf.image.resize_images(x, [int(inputs.shape[1])] * 2)
        y = tf.transpose(y, [1, 2, 0, 3])

        # in_mod is the input padded a/c to prev. convolution
        in_mod = tf.pad(inputs, [
            [0, 0],
            *([[int(np.floor((kernel_size - 1) / 2)), int(np.ceil((kernel_size - 1) / 2))]] * 2),
            [0, 0]
        ])
        # in_mod is now modded so as to preserve channels and sum over mini-batch samples for Hebbian update convolution
        in_mod = tf.transpose(in_mod, [3, 1, 2, 0])

        hebb_update = tf.nn.conv2d(input=in_mod, filter=y, strides=([1] * 4), padding='VALID')
        hebb = eta * tf.transpose(hebb_update, [1, 2, 0, 3]) + (1 - eta) * hebb
        
    return tf.nn.leaky_relu(tf.layers.batch_normalization(x))

# %%
def residual_block(inputs, filters, scope_name, eta=None):
    with tf.variable_scope(scope_name):
        x = conv_layer(inputs, scope_name='blk_layer_1', eta=eta, filters=filters, kernel_size=1)
        x = conv_layer(inputs, scope_name='blk_layer_2', eta=eta, filters=(filters * 2))
    return x + inputs

# %%
def darknet_block(inputs, filters, repetitions, scope_name, eta=None):
    with tf.variable_scope(scope_name):
        x = conv_layer(inputs, scope_name='blk_layer_0', eta=eta, filters=filters, strides=2)
        for i in range(repetitions):
            x = residual_block(x, filters / 2, scope_name='blk_rep_' + str(i), eta=eta)
    return x

# %%
def darknet_model(features, labels, mode):  
    features = tf.cast(features, dtype=tf.float32)
    
    eta = tf.get_variable('eta', (1,), initializer=tf.truncated_normal_initializer)
    
    x = conv_layer(features, scope_name='first', eta=eta, filters=32)
    x = darknet_block(x, filters=64, repetitions=1, scope_name='dark_blk_0', eta=eta)
    x = darknet_block(x, filters=128, repetitions=2, scope_name='dark_blk_1', eta=eta)
    x = darknet_block(x, filters=256, repetitions=8, scope_name='dark_blk_2', eta=eta)
    x = darknet_block(x, filters=512, repetitions=8, scope_name='dark_blk_3', eta=eta)
    x = darknet_block(x, filters=1024, repetitions=4, scope_name='dark_blk_4')
    
    x = tf.layers.average_pooling2d(x, pool_size=8, strides=8)
    x = tf.layers.flatten(x)
    x = tf.layers.dense(inputs=x, units=20, kernel_initializer=tf.truncated_normal_initializer())
    
    classes = tf.where(tf.sigmoid(x) >= 0.5, tf.ones_like(x, dtype=tf.float32), tf.zeros_like(x, dtype=tf.float32))
    correct_prediction = tf.equal(classes, labels)
    acc = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    acc = tf.identity(acc, name='accuracy_tensor')
    
    predictions = {'classes': classes, 'accuracy': acc}
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)
    
    loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=labels, logits=x)
    loss = tf.reduce_mean(loss)
    
    tf.summary.scalar('accuracy', acc)
    tf.summary.scalar('loss', loss)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.contrib.estimator.TowerOptimizer(tf.train.AdamOptimizer(1e-4))
        train_op = optimizer.minimize(loss=loss, global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

    eval_metric_ops = {'accuracy': tf.metrics.accuracy(labels=labels, predictions=classes)}
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss,
                                      eval_metric_ops=eval_metric_ops)

# %%
tensors_to_log = {'accuracy': 'accuracy_tensor'}
logging_hook = tf.train.LoggingTensorHook(tensors=tensors_to_log, every_n_iter=10)

# %%
model = tf.estimator.Estimator(
    model_fn=tf.contrib.estimator.replicate_model_fn(darknet_model),
    model_dir='/tmp/tmpupper', config=tf.estimator.RunConfig(
        save_checkpoints_steps=150, save_summary_steps=10, log_step_count_steps=10
    )
)
# Out:
# INFO:tensorflow:Replicating the `model_fn` across ['/device:GPU:0', '/device:GPU:1'].  Variables are going to be placed on ['/CPU:0'].  Consolidation device is going to be /CPU:0.
# INFO:tensorflow:Using config: {'_task_type': 'worker', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f5e3318c8d0>, '_model_dir': '/tmp/tmpupper', '_log_step_count_steps': 10, '_num_ps_replicas': 0, '_tf_random_seed': None, '_save_summary_steps': 10, '_save_checkpoints_steps': 150, '_service': None, '_keep_checkpoint_max': 5, '_session_config': None, '_save_checkpoints_secs': None, '_evaluation_master': '', '_is_chief': True, '_train_distribute': None, '_num_worker_replicas': 1, '_master': '', '_global_id_in_cluster': 0, '_keep_checkpoint_every_n_hours': 10000, '_task_id': 0}
# WARNING:tensorflow:Estimator's model_fn (<function _replicate_model_fn_with_mode.<locals>.replicated_model_fn at 0x7f5e3318bd90>) includes params argument, but params are not passed to Estimator.

# %%
validation_hook = tf.contrib.learn.monitors.replace_monitors_with_hooks(
    [tf.contrib.learn.monitors.ValidationMonitor(
        input_fn=lambda:train_input_fn()[1], every_n_steps=100, early_stopping_rounds=200
    )],
    model
)[0]
# Out:
# WARNING:tensorflow:From /users/misc/rharish/resnet_venv/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:279: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.

# %%
max_steps = int(((1 - VALIDATION_SPLIT) * TRAIN_LENGTH / BATCH_SIZE) * EPOCHS)
model.train(input_fn=lambda:train_input_fn()[0], hooks=[logging_hook, validation_hook],
            max_steps=max_steps)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpupper/model.ckpt.
# INFO:tensorflow:accuracy = 0.421875
# INFO:tensorflow:step = 0, loss = 167.94116
# INFO:tensorflow:global_step/sec: 1.67602
# INFO:tensorflow:accuracy = 0.921875 (5.968 sec)
# INFO:tensorflow:step = 10, loss = 1.5161915 (5.967 sec)
# INFO:tensorflow:global_step/sec: 2.26337
# INFO:tensorflow:accuracy = 0.946875 (4.418 sec)
# INFO:tensorflow:step = 20, loss = 0.35078222 (4.418 sec)
# INFO:tensorflow:global_step/sec: 2.25644
# INFO:tensorflow:accuracy = 0.928125 (4.432 sec)
# INFO:tensorflow:step = 30, loss = 0.23873076 (4.432 sec)
# INFO:tensorflow:global_step/sec: 2.27079
# INFO:tensorflow:accuracy = 0.953125 (4.404 sec)
# INFO:tensorflow:step = 40, loss = 0.20252994 (4.404 sec)
# INFO:tensorflow:global_step/sec: 2.2758
# INFO:tensorflow:accuracy = 0.9375 (4.394 sec)
# INFO:tensorflow:step = 50, loss = 0.17234951 (4.394 sec)
# INFO:tensorflow:global_step/sec: 2.28226
# INFO:tensorflow:accuracy = 0.95625 (4.381 sec)
# INFO:tensorflow:step = 60, loss = 0.18166044 (4.381 sec)
# INFO:tensorflow:global_step/sec: 2.59309
# INFO:tensorflow:accuracy = 0.94375 (3.856 sec)
# INFO:tensorflow:step = 70, loss = 0.1672748 (3.856 sec)
# INFO:tensorflow:global_step/sec: 2.63113
# INFO:tensorflow:accuracy = 0.93125 (3.801 sec)
# INFO:tensorflow:step = 80, loss = 0.19695552 (3.801 sec)
# INFO:tensorflow:global_step/sec: 2.6438
# INFO:tensorflow:accuracy = 0.95 (3.782 sec)
# INFO:tensorflow:step = 90, loss = 0.18491021 (3.782 sec)
# INFO:tensorflow:global_step/sec: 2.63969
# INFO:tensorflow:accuracy = 0.93125 (3.788 sec)
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-01:22:13
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpupper/model.ckpt-1
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-11-01:24:09
# INFO:tensorflow:Saving dict for global step 1: accuracy = 0.84148437, global_step = 1, loss = 77.727066
# INFO:tensorflow:Validation (step 100): global_step = 1, accuracy = 0.84148437, loss = 77.727066
# INFO:tensorflow:step = 100, loss = 0.2135511 (124.475 sec)
# INFO:tensorflow:global_step/sec: 0.080343
# INFO:tensorflow:accuracy = 0.946875 (124.466 sec)
# INFO:tensorflow:step = 110, loss = 0.17668563 (3.780 sec)
# INFO:tensorflow:global_step/sec: 2.6454
# INFO:tensorflow:accuracy = 0.94375 (3.780 sec)
# INFO:tensorflow:step = 120, loss = 0.1725581 (3.780 sec)
# INFO:tensorflow:global_step/sec: 2.65126
# INFO:tensorflow:accuracy = 0.95 (3.772 sec)
# INFO:tensorflow:step = 130, loss = 0.1949924 (3.772 sec)
# INFO:tensorflow:global_step/sec: 2.6504
# INFO:tensorflow:accuracy = 0.978125 (3.773 sec)
# INFO:tensorflow:step = 140, loss = 0.15072802 (3.773 sec)
# INFO:tensorflow:Saving checkpoints for 151 into /tmp/tmpupper/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.89523
# INFO:tensorflow:accuracy = 0.9375 (5.277 sec)
# INFO:tensorflow:step = 150, loss = 0.1914604 (5.277 sec)
# INFO:tensorflow:global_step/sec: 2.63693
# INFO:tensorflow:accuracy = 0.903125 (3.792 sec)
# INFO:tensorflow:step = 160, loss = 0.20292339 (3.792 sec)
# INFO:tensorflow:global_step/sec: 2.64596
# INFO:tensorflow:accuracy = 0.94375 (3.779 sec)
# INFO:tensorflow:step = 170, loss = 0.1886745 (3.779 sec)
# INFO:tensorflow:global_step/sec: 2.64096
# INFO:tensorflow:accuracy = 0.965625 (3.787 sec)
# INFO:tensorflow:step = 180, loss = 0.1503743 (3.787 sec)
# INFO:tensorflow:global_step/sec: 2.64369
# INFO:tensorflow:accuracy = 0.9375 (3.783 sec)
# INFO:tensorflow:step = 190, loss = 0.20053348 (3.783 sec)
# INFO:tensorflow:global_step/sec: 2.63771
# INFO:tensorflow:accuracy = 0.94375 (3.791 sec)
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-01:24:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpupper/model.ckpt-151
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-11-01:26:52
# INFO:tensorflow:Saving dict for global step 151: accuracy = 0.9189453, global_step = 151, loss = 0.24097529
# INFO:tensorflow:Validation (step 200): global_step = 151, accuracy = 0.9189453, loss = 0.24097529
# INFO:tensorflow:step = 200, loss = 0.19042662 (126.418 sec)
# INFO:tensorflow:global_step/sec: 0.0788322
# INFO:tensorflow:accuracy = 0.953125 (126.852 sec)
# INFO:tensorflow:step = 210, loss = 0.18641222 (4.225 sec)
# INFO:tensorflow:global_step/sec: 2.66114
# INFO:tensorflow:accuracy = 0.9375 (3.758 sec)
# INFO:tensorflow:step = 220, loss = 0.19059995 (3.758 sec)
# INFO:tensorflow:global_step/sec: 2.65337
# INFO:tensorflow:accuracy = 0.940625 (3.769 sec)
# INFO:tensorflow:step = 230, loss = 0.20245224 (3.769 sec)
# INFO:tensorflow:global_step/sec: 2.65708
# INFO:tensorflow:accuracy = 0.940625 (3.763 sec)
# INFO:tensorflow:step = 240, loss = 0.18351005 (3.763 sec)
# INFO:tensorflow:global_step/sec: 2.65596
# INFO:tensorflow:accuracy = 0.95 (3.765 sec)
# INFO:tensorflow:step = 250, loss = 0.1798078 (3.765 sec)
# INFO:tensorflow:global_step/sec: 2.6609
# INFO:tensorflow:accuracy = 0.9375 (3.758 sec)
# INFO:tensorflow:step = 260, loss = 0.18071736 (3.758 sec)
# INFO:tensorflow:global_step/sec: 2.6521
# INFO:tensorflow:accuracy = 0.9375 (3.771 sec)
# INFO:tensorflow:step = 270, loss = 0.17712182 (3.771 sec)
# INFO:tensorflow:global_step/sec: 2.64658
# INFO:tensorflow:accuracy = 0.940625 (3.778 sec)
# INFO:tensorflow:step = 280, loss = 0.21664195 (3.778 sec)
# INFO:tensorflow:global_step/sec: 2.65488
# INFO:tensorflow:accuracy = 0.94375 (3.767 sec)
# INFO:tensorflow:step = 290, loss = 0.17301518 (3.767 sec)
# INFO:tensorflow:Saving checkpoints for 301 into /tmp/tmpupper/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.89256
# INFO:tensorflow:accuracy = 0.946875 (5.285 sec)
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-01:27:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpupper/model.ckpt-301
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-11-01:29:34
# INFO:tensorflow:Saving dict for global step 301: accuracy = 0.9191699, global_step = 301, loss = 0.24035892
# INFO:tensorflow:Validation (step 300): global_step = 301, accuracy = 0.9191699, loss = 0.24035892
# INFO:tensorflow:step = 300, loss = 0.16552617 (127.008 sec)
# INFO:tensorflow:global_step/sec: 0.0796846
# INFO:tensorflow:accuracy = 0.91875 (125.494 sec)
# INFO:tensorflow:step = 310, loss = 0.24617186 (3.771 sec)
# INFO:tensorflow:global_step/sec: 2.65748
# INFO:tensorflow:accuracy = 0.95 (3.763 sec)
# INFO:tensorflow:step = 320, loss = 0.14525828 (3.763 sec)
# INFO:tensorflow:global_step/sec: 2.65752
# INFO:tensorflow:accuracy = 0.971875 (3.763 sec)
# INFO:tensorflow:step = 330, loss = 0.17691427 (3.763 sec)
# INFO:tensorflow:global_step/sec: 2.65638
# INFO:tensorflow:accuracy = 0.946875 (3.765 sec)
# INFO:tensorflow:step = 340, loss = 0.19621035 (3.764 sec)
# INFO:tensorflow:global_step/sec: 2.66079
# INFO:tensorflow:accuracy = 0.921875 (3.758 sec)
# INFO:tensorflow:step = 350, loss = 0.22900373 (3.759 sec)
# INFO:tensorflow:global_step/sec: 2.65783
# INFO:tensorflow:accuracy = 0.946875 (3.763 sec)
# INFO:tensorflow:step = 360, loss = 0.17773744 (3.762 sec)
# INFO:tensorflow:global_step/sec: 2.65857
# INFO:tensorflow:accuracy = 0.91875 (3.761 sec)
# INFO:tensorflow:step = 370, loss = 0.21704262 (3.761 sec)
# INFO:tensorflow:global_step/sec: 0.0863279
# INFO:tensorflow:accuracy = 0.946875 (115.837 sec)
# INFO:tensorflow:step = 380, loss = 0.19457409 (115.837 sec)
# INFO:tensorflow:global_step/sec: 2.28838
# INFO:tensorflow:accuracy = 0.95 (4.370 sec)
# INFO:tensorflow:step = 390, loss = 0.21516988 (4.370 sec)
# INFO:tensorflow:global_step/sec: 2.26033
# INFO:tensorflow:accuracy = 0.90625 (4.424 sec)
# INFO:tensorflow:step = 400, loss = 0.22330093 (4.425 sec)
# INFO:tensorflow:global_step/sec: 2.27555
# INFO:tensorflow:accuracy = 0.915625 (4.395 sec)
# INFO:tensorflow:step = 410, loss = 0.2221373 (4.394 sec)
# INFO:tensorflow:global_step/sec: 2.27524
# INFO:tensorflow:accuracy = 0.93125 (4.395 sec)
# INFO:tensorflow:step = 420, loss = 0.19163156 (4.394 sec)
# INFO:tensorflow:global_step/sec: 2.26619
# INFO:tensorflow:accuracy = 0.95 (4.413 sec)
# INFO:tensorflow:step = 430, loss = 0.19835296 (4.413 sec)
# INFO:tensorflow:global_step/sec: 2.46061
# INFO:tensorflow:accuracy = 0.94375 (4.064 sec)
# INFO:tensorflow:step = 440, loss = 0.1853443 (4.064 sec)
# INFO:tensorflow:Saving checkpoints for 451 into /tmp/tmpupper/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.88996
# INFO:tensorflow:accuracy = 0.953125 (5.292 sec)
# INFO:tensorflow:step = 450, loss = 0.15512681 (5.293 sec)
# INFO:tensorflow:global_step/sec: 2.64467
# INFO:tensorflow:accuracy = 0.946875 (3.780 sec)
# INFO:tensorflow:step = 460, loss = 0.16933422 (3.779 sec)
# INFO:tensorflow:global_step/sec: 2.65885
# INFO:tensorflow:accuracy = 0.91875 (3.761 sec)
# INFO:tensorflow:step = 470, loss = 0.21231374 (3.761 sec)
# INFO:tensorflow:global_step/sec: 2.65451
# INFO:tensorflow:accuracy = 0.940625 (3.767 sec)
# INFO:tensorflow:step = 480, loss = 0.18477565 (3.767 sec)
# INFO:tensorflow:global_step/sec: 2.65379
# INFO:tensorflow:accuracy = 0.946875 (3.768 sec)
# INFO:tensorflow:step = 490, loss = 0.15774974 (3.768 sec)
# INFO:tensorflow:global_step/sec: 2.6531
# INFO:tensorflow:accuracy = 0.9625 (3.769 sec)
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-01:32:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpupper/model.ckpt-451
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-11-01:34:50
# INFO:tensorflow:Saving dict for global step 451: accuracy = 0.9190625, global_step = 451, loss = 0.23949964
# INFO:tensorflow:Validation (step 500): global_step = 451, accuracy = 0.9190625, loss = 0.23949964
# INFO:tensorflow:step = 500, loss = 0.13931891 (127.307 sec)
# INFO:tensorflow:global_step/sec: 0.0785411
# INFO:tensorflow:accuracy = 0.95625 (127.322 sec)
# INFO:tensorflow:step = 510, loss = 0.16672677 (3.784 sec)
# INFO:tensorflow:global_step/sec: 2.65793
# INFO:tensorflow:accuracy = 0.953125 (3.762 sec)
# INFO:tensorflow:step = 520, loss = 0.14340171 (3.762 sec)
# INFO:tensorflow:global_step/sec: 2.65638
# INFO:tensorflow:accuracy = 0.946875 (3.765 sec)
# INFO:tensorflow:step = 530, loss = 0.17534286 (3.764 sec)
# INFO:tensorflow:global_step/sec: 2.65951
# INFO:tensorflow:accuracy = 0.95625 (3.760 sec)
# INFO:tensorflow:step = 540, loss = 0.150493 (3.760 sec)
# INFO:tensorflow:global_step/sec: 2.65671
# INFO:tensorflow:accuracy = 0.95625 (3.764 sec)
# INFO:tensorflow:step = 550, loss = 0.17931727 (3.764 sec)
# INFO:tensorflow:global_step/sec: 2.65859
# INFO:tensorflow:accuracy = 0.94375 (3.761 sec)
# INFO:tensorflow:step = 560, loss = 0.18556769 (3.761 sec)
# INFO:tensorflow:global_step/sec: 2.64783
# INFO:tensorflow:accuracy = 0.940625 (3.777 sec)
# INFO:tensorflow:step = 570, loss = 0.19279638 (3.777 sec)
# INFO:tensorflow:global_step/sec: 2.65703
# INFO:tensorflow:accuracy = 0.953125 (3.764 sec)
# INFO:tensorflow:step = 580, loss = 0.14680919 (3.764 sec)
# INFO:tensorflow:global_step/sec: 2.65761
# INFO:tensorflow:accuracy = 0.928125 (3.763 sec)
# INFO:tensorflow:step = 590, loss = 0.17559308 (3.763 sec)
# INFO:tensorflow:Saving checkpoints for 601 into /tmp/tmpupper/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.75784
# INFO:tensorflow:accuracy = 0.9875 (5.689 sec)
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-01:35:33
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpupper/model.ckpt-601
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-11-01:37:33
# INFO:tensorflow:Saving dict for global step 601: accuracy = 0.92041016, global_step = 601, loss = 0.24535462
# INFO:tensorflow:Validation (step 600): global_step = 601, accuracy = 0.92041016, loss = 0.24535462
# INFO:tensorflow:step = 600, loss = 0.11814064 (129.020 sec)
# INFO:tensorflow:global_step/sec: 0.0786816
# INFO:tensorflow:accuracy = 0.953125 (127.094 sec)
# INFO:tensorflow:step = 610, loss = 0.14236507 (3.763 sec)
# INFO:tensorflow:global_step/sec: 2.65794
# INFO:tensorflow:accuracy = 0.965625 (3.762 sec)
# INFO:tensorflow:step = 620, loss = 0.17372167 (3.762 sec)
# INFO:tensorflow:global_step/sec: 2.65688
# INFO:tensorflow:accuracy = 0.946875 (3.764 sec)
# INFO:tensorflow:step = 630, loss = 0.1753155 (3.764 sec)
# INFO:tensorflow:global_step/sec: 2.65888
# INFO:tensorflow:accuracy = 0.953125 (3.761 sec)
# INFO:tensorflow:step = 640, loss = 0.13520667 (3.761 sec)
# INFO:tensorflow:global_step/sec: 2.65676
# INFO:tensorflow:accuracy = 0.946875 (3.764 sec)
# INFO:tensorflow:step = 650, loss = 0.17816249 (3.764 sec)
# INFO:tensorflow:global_step/sec: 2.65487
# INFO:tensorflow:accuracy = 0.953125 (3.767 sec)
# INFO:tensorflow:step = 660, loss = 0.19825497 (3.767 sec)
# INFO:tensorflow:global_step/sec: 2.65832
# INFO:tensorflow:accuracy = 0.953125 (3.762 sec)
# INFO:tensorflow:step = 670, loss = 0.17585558 (3.762 sec)
# INFO:tensorflow:global_step/sec: 2.65664
# INFO:tensorflow:accuracy = 0.95625 (3.764 sec)
# INFO:tensorflow:step = 680, loss = 0.17923081 (3.764 sec)
# INFO:tensorflow:global_step/sec: 2.65358
# INFO:tensorflow:accuracy = 0.946875 (3.769 sec)
# INFO:tensorflow:step = 690, loss = 0.18154937 (3.768 sec)
# INFO:tensorflow:global_step/sec: 2.64402
# INFO:tensorflow:accuracy = 0.928125 (3.782 sec)
# INFO:tensorflow:step = 700, loss = 0.2029215 (3.783 sec)
# INFO:tensorflow:global_step/sec: 2.64445
# INFO:tensorflow:accuracy = 0.965625 (3.781 sec)
# INFO:tensorflow:step = 710, loss = 0.18910682 (3.780 sec)
# INFO:tensorflow:global_step/sec: 2.64793
# INFO:tensorflow:accuracy = 0.96875 (3.777 sec)
# INFO:tensorflow:step = 720, loss = 0.16930544 (3.777 sec)
# INFO:tensorflow:global_step/sec: 2.64049
# INFO:tensorflow:accuracy = 0.940625 (3.787 sec)
# INFO:tensorflow:step = 730, loss = 0.19544321 (3.787 sec)
# INFO:tensorflow:global_step/sec: 2.65391
# INFO:tensorflow:accuracy = 0.9375 (3.768 sec)
# INFO:tensorflow:step = 740, loss = 0.19323304 (3.768 sec)
# INFO:tensorflow:Saving checkpoints for 751 into /tmp/tmpupper/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.085173
# INFO:tensorflow:accuracy = 0.9375 (117.409 sec)
# INFO:tensorflow:step = 750, loss = 0.20266774 (117.409 sec)
# INFO:tensorflow:global_step/sec: 2.19675
# INFO:tensorflow:accuracy = 0.93125 (4.551 sec)
# INFO:tensorflow:step = 760, loss = 0.18438086 (4.551 sec)
# INFO:tensorflow:global_step/sec: 2.27236
# INFO:tensorflow:accuracy = 0.94375 (4.401 sec)
# INFO:tensorflow:step = 770, loss = 0.18643805 (4.401 sec)
# INFO:tensorflow:global_step/sec: 2.26145
# INFO:tensorflow:accuracy = 0.940625 (4.422 sec)
# INFO:tensorflow:step = 780, loss = 0.17070551 (4.422 sec)
# INFO:tensorflow:global_step/sec: 2.27858
# INFO:tensorflow:accuracy = 0.946875 (4.389 sec)
# INFO:tensorflow:step = 790, loss = 0.15610173 (4.389 sec)
# INFO:tensorflow:global_step/sec: 2.29574
# INFO:tensorflow:accuracy = 0.9375 (4.356 sec)
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-01:40:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpupper/model.ckpt-751
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-11-01:42:49
# INFO:tensorflow:Saving dict for global step 751: accuracy = 0.91984373, global_step = 751, loss = 0.23471923
# INFO:tensorflow:Validation (step 800): global_step = 751, accuracy = 0.91984373, loss = 0.23471923
# INFO:tensorflow:step = 800, loss = 0.16258599 (128.772 sec)
# INFO:tensorflow:global_step/sec: 0.0775616
# INFO:tensorflow:accuracy = 0.95625 (128.930 sec)
# INFO:tensorflow:step = 810, loss = 0.15618311 (4.513 sec)
# INFO:tensorflow:global_step/sec: 2.6543
# INFO:tensorflow:accuracy = 0.946875 (3.767 sec)
# INFO:tensorflow:step = 820, loss = 0.17598602 (3.767 sec)
# INFO:tensorflow:global_step/sec: 2.65572
# INFO:tensorflow:accuracy = 0.93125 (3.765 sec)
# INFO:tensorflow:step = 830, loss = 0.17954183 (3.765 sec)
# INFO:tensorflow:global_step/sec: 2.6623
# INFO:tensorflow:accuracy = 0.925 (3.756 sec)
# INFO:tensorflow:step = 840, loss = 0.21698421 (3.756 sec)
# INFO:tensorflow:global_step/sec: 2.65777
# INFO:tensorflow:accuracy = 0.965625 (3.762 sec)
# INFO:tensorflow:step = 850, loss = 0.14658873 (3.762 sec)
# INFO:tensorflow:global_step/sec: 2.65592
# INFO:tensorflow:accuracy = 0.953125 (3.765 sec)
# INFO:tensorflow:step = 860, loss = 0.17321393 (3.765 sec)
# INFO:tensorflow:global_step/sec: 2.65509
# INFO:tensorflow:accuracy = 0.940625 (3.766 sec)
# INFO:tensorflow:step = 870, loss = 0.18326941 (3.766 sec)
# INFO:tensorflow:global_step/sec: 2.65435
# INFO:tensorflow:accuracy = 0.94375 (3.768 sec)
# INFO:tensorflow:step = 880, loss = 0.19229382 (3.768 sec)
# INFO:tensorflow:global_step/sec: 2.65653
# INFO:tensorflow:accuracy = 0.93125 (3.764 sec)
# INFO:tensorflow:step = 890, loss = 0.1923301 (3.765 sec)
# INFO:tensorflow:Saving checkpoints for 901 into /tmp/tmpupper/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.85564
# INFO:tensorflow:accuracy = 0.921875 (5.389 sec)
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-01:43:33
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpupper/model.ckpt-901
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-11-01:45:33
# INFO:tensorflow:Saving dict for global step 901: accuracy = 0.9219043, global_step = 901, loss = 0.23465009
# INFO:tensorflow:Validation (step 900): global_step = 901, accuracy = 0.9219043, loss = 0.23465009
# INFO:tensorflow:step = 900, loss = 0.20769191 (129.199 sec)
# INFO:tensorflow:global_step/sec: 0.0783867
# INFO:tensorflow:accuracy = 0.96875 (127.573 sec)
# INFO:tensorflow:step = 910, loss = 0.14116225 (3.763 sec)
# INFO:tensorflow:global_step/sec: 2.65635
# INFO:tensorflow:accuracy = 0.946875 (3.765 sec)
# INFO:tensorflow:step = 920, loss = 0.15982768 (3.765 sec)
# INFO:tensorflow:global_step/sec: 2.65978
# INFO:tensorflow:accuracy = 0.953125 (3.760 sec)
# INFO:tensorflow:step = 930, loss = 0.17637804 (3.760 sec)
# INFO:tensorflow:global_step/sec: 2.65729
# INFO:tensorflow:accuracy = 0.946875 (3.763 sec)
# INFO:tensorflow:step = 940, loss = 0.18032348 (3.763 sec)
# INFO:tensorflow:global_step/sec: 2.65793
# INFO:tensorflow:accuracy = 0.93125 (3.762 sec)
# INFO:tensorflow:step = 950, loss = 0.20288326 (3.763 sec)
# INFO:tensorflow:global_step/sec: 2.65178
# INFO:tensorflow:accuracy = 0.959375 (3.771 sec)
# INFO:tensorflow:step = 960, loss = 0.15084332 (3.770 sec)
# INFO:tensorflow:global_step/sec: 2.65263
# INFO:tensorflow:accuracy = 0.94375 (3.770 sec)
# INFO:tensorflow:step = 970, loss = 0.21797693 (3.770 sec)
# INFO:tensorflow:global_step/sec: 2.65612
# INFO:tensorflow:accuracy = 0.96875 (3.765 sec)
# INFO:tensorflow:step = 980, loss = 0.1481978 (3.765 sec)
# INFO:tensorflow:global_step/sec: 2.64934
# INFO:tensorflow:accuracy = 0.96875 (3.774 sec)
# INFO:tensorflow:step = 990, loss = 0.1468933 (3.774 sec)
# INFO:tensorflow:global_step/sec: 2.64473
# INFO:tensorflow:accuracy = 0.940625 (3.781 sec)
# INFO:tensorflow:step = 1000, loss = 0.16478044 (3.782 sec)
# INFO:tensorflow:global_step/sec: 2.64489
# INFO:tensorflow:accuracy = 0.94375 (3.781 sec)
# INFO:tensorflow:step = 1010, loss = 0.16942398 (3.780 sec)
# INFO:tensorflow:global_step/sec: 2.64222
# INFO:tensorflow:accuracy = 0.953125 (3.785 sec)
# INFO:tensorflow:step = 1020, loss = 0.1818155 (3.785 sec)
# INFO:tensorflow:global_step/sec: 2.64582
# INFO:tensorflow:accuracy = 0.940625 (3.779 sec)
# INFO:tensorflow:step = 1030, loss = 0.209181 (3.779 sec)
# INFO:tensorflow:global_step/sec: 2.64928
# INFO:tensorflow:accuracy = 0.953125 (3.775 sec)
# INFO:tensorflow:step = 1040, loss = 0.1759488 (3.775 sec)
# INFO:tensorflow:Saving checkpoints for 1051 into /tmp/tmpupper/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.85331
# INFO:tensorflow:accuracy = 0.9625 (5.396 sec)
# INFO:tensorflow:step = 1050, loss = 0.16305234 (5.396 sec)
# INFO:tensorflow:global_step/sec: 2.64491
# INFO:tensorflow:accuracy = 0.9375 (3.781 sec)
# INFO:tensorflow:step = 1060, loss = 0.1877327 (3.781 sec)
# INFO:tensorflow:global_step/sec: 2.64148
# INFO:tensorflow:accuracy = 0.95625 (3.786 sec)
# INFO:tensorflow:step = 1070, loss = 0.16504994 (3.786 sec)
# INFO:tensorflow:global_step/sec: 2.64048
# INFO:tensorflow:accuracy = 0.959375 (3.787 sec)
# INFO:tensorflow:step = 1080, loss = 0.16449456 (3.787 sec)
# INFO:tensorflow:global_step/sec: 2.64829
# INFO:tensorflow:accuracy = 0.953125 (3.776 sec)
# INFO:tensorflow:step = 1090, loss = 0.17370835 (3.776 sec)
# INFO:tensorflow:global_step/sec: 2.64072
# INFO:tensorflow:accuracy = 0.94375 (3.787 sec)
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-01:46:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpupper/model.ckpt-1051
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-11-01:48:55
# INFO:tensorflow:Saving dict for global step 1051: accuracy = 0.9219043, global_step = 1051, loss = 0.22731593
# INFO:tensorflow:Validation (step 1100): global_step = 1051, accuracy = 0.9219043, loss = 0.22731593
# INFO:tensorflow:step = 1100, loss = 0.18053153 (128.154 sec)
# INFO:tensorflow:global_step/sec: 0.0780446
# INFO:tensorflow:accuracy = 0.915625 (128.132 sec)
# INFO:tensorflow:step = 1110, loss = 0.21327633 (3.765 sec)
# INFO:tensorflow:global_step/sec: 2.65911
# INFO:tensorflow:accuracy = 0.95625 (3.761 sec)
# INFO:tensorflow:step = 1120, loss = 0.17645201 (3.761 sec)
# INFO:tensorflow:global_step/sec: 0.0858397
# INFO:tensorflow:accuracy = 0.95625 (116.496 sec)
# INFO:tensorflow:step = 1130, loss = 0.1494984 (116.496 sec)
# INFO:tensorflow:global_step/sec: 2.27282
# INFO:tensorflow:accuracy = 0.940625 (4.400 sec)
# INFO:tensorflow:step = 1140, loss = 0.1515273 (4.400 sec)
# INFO:tensorflow:global_step/sec: 2.25781
# INFO:tensorflow:accuracy = 0.9375 (4.429 sec)
# INFO:tensorflow:step = 1150, loss = 0.19577488 (4.429 sec)
# INFO:tensorflow:global_step/sec: 2.27354
# INFO:tensorflow:accuracy = 0.95 (4.398 sec)
# INFO:tensorflow:step = 1160, loss = 0.15767339 (4.398 sec)
# INFO:tensorflow:global_step/sec: 2.28507
# INFO:tensorflow:accuracy = 0.934375 (4.376 sec)
# INFO:tensorflow:step = 1170, loss = 0.17604586 (4.376 sec)
# INFO:tensorflow:global_step/sec: 2.26643
# INFO:tensorflow:accuracy = 0.95 (4.412 sec)
# INFO:tensorflow:step = 1180, loss = 0.15743849 (4.412 sec)
# INFO:tensorflow:global_step/sec: 2.53444
# INFO:tensorflow:accuracy = 0.9375 (3.946 sec)
# INFO:tensorflow:step = 1190, loss = 0.1894953 (3.946 sec)
# INFO:tensorflow:Saving checkpoints for 1201 into /tmp/tmpupper/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.87256
# INFO:tensorflow:accuracy = 0.934375 (5.341 sec)
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-01:51:33
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpupper/model.ckpt-1201
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-11-01:53:31
# INFO:tensorflow:Saving dict for global step 1201: accuracy = 0.92160153, global_step = 1201, loss = 0.22746806
# INFO:tensorflow:Validation (step 1200): global_step = 1201, accuracy = 0.92160153, loss = 0.22746806
# INFO:tensorflow:step = 1200, loss = 0.18363535 (126.063 sec)
# INFO:tensorflow:global_step/sec: 0.0803307
# INFO:tensorflow:accuracy = 0.953125 (124.485 sec)
# INFO:tensorflow:step = 1210, loss = 0.1489293 (3.762 sec)
# INFO:tensorflow:global_step/sec: 2.65631
# INFO:tensorflow:accuracy = 0.925 (3.765 sec)
# INFO:tensorflow:step = 1220, loss = 0.22511315 (3.765 sec)
# INFO:tensorflow:global_step/sec: 2.65786
# INFO:tensorflow:accuracy = 0.95625 (3.762 sec)
# INFO:tensorflow:step = 1230, loss = 0.16018516 (3.762 sec)
# INFO:tensorflow:global_step/sec: 2.65501
# INFO:tensorflow:accuracy = 0.93125 (3.766 sec)
# INFO:tensorflow:step = 1240, loss = 0.17971927 (3.767 sec)
# INFO:tensorflow:global_step/sec: 2.65695
# INFO:tensorflow:accuracy = 0.95625 (3.764 sec)
# INFO:tensorflow:step = 1250, loss = 0.16889033 (3.764 sec)
# INFO:tensorflow:global_step/sec: 2.65595
# INFO:tensorflow:accuracy = 0.940625 (3.765 sec)
# INFO:tensorflow:step = 1260, loss = 0.16887942 (3.765 sec)
# INFO:tensorflow:global_step/sec: 2.65737
# INFO:tensorflow:accuracy = 0.9625 (3.763 sec)
# INFO:tensorflow:step = 1270, loss = 0.16509286 (3.763 sec)
# INFO:tensorflow:global_step/sec: 2.65953
# INFO:tensorflow:accuracy = 0.94375 (3.760 sec)
# INFO:tensorflow:step = 1280, loss = 0.1969862 (3.760 sec)
# INFO:tensorflow:global_step/sec: 2.64995
# INFO:tensorflow:accuracy = 0.928125 (3.774 sec)
# INFO:tensorflow:step = 1290, loss = 0.21766907 (3.774 sec)
# INFO:tensorflow:global_step/sec: 2.64849
# INFO:tensorflow:accuracy = 0.925 (3.776 sec)
# INFO:tensorflow:step = 1300, loss = 0.22852871 (3.777 sec)
# INFO:tensorflow:global_step/sec: 2.63902
# INFO:tensorflow:accuracy = 0.95 (3.789 sec)
# INFO:tensorflow:step = 1310, loss = 0.14205024 (3.788 sec)
# INFO:tensorflow:global_step/sec: 2.64759
# INFO:tensorflow:accuracy = 0.940625 (3.777 sec)
# INFO:tensorflow:step = 1320, loss = 0.15642552 (3.777 sec)
# INFO:tensorflow:global_step/sec: 2.64613
# INFO:tensorflow:accuracy = 0.91875 (3.779 sec)
# INFO:tensorflow:step = 1330, loss = 0.19750741 (3.779 sec)
# INFO:tensorflow:global_step/sec: 2.64671
# INFO:tensorflow:accuracy = 0.94375 (3.778 sec)
# INFO:tensorflow:step = 1340, loss = 0.16551545 (3.778 sec)
# INFO:tensorflow:Saving checkpoints for 1351 into /tmp/tmpupper/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.83164
# INFO:tensorflow:accuracy = 0.925 (5.460 sec)
# INFO:tensorflow:step = 1350, loss = 0.19936058 (5.460 sec)
# INFO:tensorflow:global_step/sec: 2.6338
# INFO:tensorflow:accuracy = 0.971875 (3.796 sec)
# INFO:tensorflow:step = 1360, loss = 0.16700181 (3.796 sec)
# INFO:tensorflow:global_step/sec: 2.63455
# INFO:tensorflow:accuracy = 0.946875 (3.796 sec)
# INFO:tensorflow:step = 1370, loss = 0.16123244 (3.796 sec)
# INFO:tensorflow:global_step/sec: 2.64371
# INFO:tensorflow:accuracy = 0.93125 (3.782 sec)
# INFO:tensorflow:step = 1380, loss = 0.19833684 (3.782 sec)
# INFO:tensorflow:global_step/sec: 2.64906
# INFO:tensorflow:accuracy = 0.95625 (3.775 sec)
# INFO:tensorflow:step = 1390, loss = 0.17632395 (3.775 sec)
# INFO:tensorflow:global_step/sec: 2.63711
# INFO:tensorflow:accuracy = 0.96875 (3.792 sec)
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-01:54:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpupper/model.ckpt-1351
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-11-01:56:52
# INFO:tensorflow:Saving dict for global step 1351: accuracy = 0.9231836, global_step = 1351, loss = 0.21991663
# INFO:tensorflow:Validation (step 1400): global_step = 1351, accuracy = 0.9231836, loss = 0.21991663
# INFO:tensorflow:step = 1400, loss = 0.16631114 (127.573 sec)
# INFO:tensorflow:global_step/sec: 0.0784018
# INFO:tensorflow:accuracy = 0.940625 (127.548 sec)
# INFO:tensorflow:step = 1410, loss = 0.19636193 (3.767 sec)
# INFO:tensorflow:global_step/sec: 2.66063
# INFO:tensorflow:accuracy = 0.959375 (3.758 sec)
# INFO:tensorflow:step = 1420, loss = 0.17137262 (3.759 sec)
# INFO:tensorflow:global_step/sec: 2.65676
# INFO:tensorflow:accuracy = 0.9375 (3.764 sec)
# INFO:tensorflow:step = 1430, loss = 0.16840258 (3.764 sec)
# INFO:tensorflow:global_step/sec: 2.65693
# INFO:tensorflow:accuracy = 0.96875 (3.764 sec)
# INFO:tensorflow:step = 1440, loss = 0.16298237 (3.764 sec)
# INFO:tensorflow:global_step/sec: 2.65772
# INFO:tensorflow:accuracy = 0.925 (3.763 sec)
# INFO:tensorflow:step = 1450, loss = 0.19526574 (3.763 sec)
# INFO:tensorflow:global_step/sec: 2.65983
# INFO:tensorflow:accuracy = 0.965625 (3.760 sec)
# INFO:tensorflow:step = 1460, loss = 0.1258145 (3.760 sec)
# INFO:tensorflow:global_step/sec: 2.65491
# INFO:tensorflow:accuracy = 0.978125 (3.767 sec)
# INFO:tensorflow:step = 1470, loss = 0.15047154 (3.767 sec)
# INFO:tensorflow:global_step/sec: 2.66021
# INFO:tensorflow:accuracy = 0.95 (3.759 sec)
# INFO:tensorflow:step = 1480, loss = 0.18879119 (3.759 sec)
# INFO:tensorflow:global_step/sec: 2.64813
# INFO:tensorflow:accuracy = 0.95625 (3.776 sec)
# INFO:tensorflow:step = 1490, loss = 0.16301188 (3.776 sec)
# INFO:tensorflow:Saving checkpoints for 1501 into /tmp/tmpupper/model.ckpt.
# INFO:tensorflow:global_step/sec: 0.0877966
# INFO:tensorflow:accuracy = 0.921875 (113.900 sec)
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-01:59:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpupper/model.ckpt-1501
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-11-02:01:22
# INFO:tensorflow:Saving dict for global step 1501: accuracy = 0.92423826, global_step = 1501, loss = 0.2199111
# INFO:tensorflow:Validation (step 1500): global_step = 1501, accuracy = 0.92423826, loss = 0.2199111
# INFO:tensorflow:step = 1500, loss = 0.18348521 (236.561 sec)
# INFO:tensorflow:global_step/sec: 0.0786231
# INFO:tensorflow:accuracy = 0.91875 (127.189 sec)
# INFO:tensorflow:step = 1510, loss = 0.23490939 (4.528 sec)
# INFO:tensorflow:global_step/sec: 2.24346
# INFO:tensorflow:accuracy = 0.95 (4.457 sec)
# INFO:tensorflow:step = 1520, loss = 0.15696858 (4.457 sec)
# INFO:tensorflow:global_step/sec: 2.25313
# INFO:tensorflow:accuracy = 0.93125 (4.438 sec)
# INFO:tensorflow:step = 1530, loss = 0.19188717 (4.438 sec)
# INFO:tensorflow:global_step/sec: 2.25857
# INFO:tensorflow:accuracy = 0.93125 (4.428 sec)
# INFO:tensorflow:step = 1540, loss = 0.23833595 (4.428 sec)
# INFO:tensorflow:global_step/sec: 2.27706
# INFO:tensorflow:accuracy = 0.928125 (4.392 sec)
# INFO:tensorflow:step = 1550, loss = 0.19061804 (4.391 sec)
# INFO:tensorflow:global_step/sec: 2.37223
# INFO:tensorflow:accuracy = 0.934375 (4.215 sec)
# INFO:tensorflow:step = 1560, loss = 0.1629484 (4.215 sec)
# INFO:tensorflow:global_step/sec: 2.64997
# INFO:tensorflow:accuracy = 0.940625 (3.774 sec)
# INFO:tensorflow:step = 1570, loss = 0.15379968 (3.774 sec)
# INFO:tensorflow:global_step/sec: 2.65252
# INFO:tensorflow:accuracy = 0.946875 (3.770 sec)
# INFO:tensorflow:step = 1580, loss = 0.16686147 (3.770 sec)
# INFO:tensorflow:global_step/sec: 2.65268
# INFO:tensorflow:accuracy = 0.946875 (3.770 sec)
# INFO:tensorflow:step = 1590, loss = 0.16834162 (3.770 sec)
# INFO:tensorflow:global_step/sec: 2.6497
# INFO:tensorflow:accuracy = 0.94375 (3.774 sec)
# INFO:tensorflow:step = 1600, loss = 0.16423273 (3.775 sec)
# INFO:tensorflow:global_step/sec: 2.64989
# INFO:tensorflow:accuracy = 0.946875 (3.774 sec)
# INFO:tensorflow:step = 1610, loss = 0.19670117 (3.773 sec)
# INFO:tensorflow:global_step/sec: 2.64763
# INFO:tensorflow:accuracy = 0.94375 (3.777 sec)
# INFO:tensorflow:step = 1620, loss = 0.18605644 (3.777 sec)
# INFO:tensorflow:global_step/sec: 2.64377
# INFO:tensorflow:accuracy = 0.95 (3.782 sec)
# INFO:tensorflow:step = 1630, loss = 0.16852494 (3.783 sec)
# INFO:tensorflow:global_step/sec: 2.64745
# INFO:tensorflow:accuracy = 0.946875 (3.777 sec)
# INFO:tensorflow:step = 1640, loss = 0.13403401 (3.777 sec)
# INFO:tensorflow:Saving checkpoints for 1651 into /tmp/tmpupper/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.86798
# INFO:tensorflow:accuracy = 0.946875 (5.353 sec)
# INFO:tensorflow:step = 1650, loss = 0.18045282 (5.354 sec)
# INFO:tensorflow:global_step/sec: 2.64202
# INFO:tensorflow:accuracy = 0.9375 (3.785 sec)
# INFO:tensorflow:step = 1660, loss = 0.18838063 (3.785 sec)
# INFO:tensorflow:global_step/sec: 2.64521
# INFO:tensorflow:accuracy = 0.965625 (3.780 sec)
# INFO:tensorflow:step = 1670, loss = 0.16490415 (3.780 sec)
# INFO:tensorflow:global_step/sec: 2.64296
# INFO:tensorflow:accuracy = 0.95 (3.784 sec)
# INFO:tensorflow:step = 1680, loss = 0.18467006 (3.784 sec)
# INFO:tensorflow:global_step/sec: 2.64165
# INFO:tensorflow:accuracy = 0.959375 (3.786 sec)
# INFO:tensorflow:step = 1690, loss = 0.15158032 (3.786 sec)
# INFO:tensorflow:global_step/sec: 2.6367
# INFO:tensorflow:accuracy = 0.946875 (3.793 sec)
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-02:02:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpupper/model.ckpt-1651
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-11-02:04:48
# INFO:tensorflow:Saving dict for global step 1651: accuracy = 0.923457, global_step = 1651, loss = 0.2202893
# INFO:tensorflow:Validation (step 1700): global_step = 1651, accuracy = 0.923457, loss = 0.2202893
# INFO:tensorflow:Stopping. Best step: 1500 with loss = 0.2199110984802246.
# INFO:tensorflow:step = 1700, loss = 0.14184755 (128.606 sec)
# INFO:tensorflow:Saving checkpoints for 1701 into /tmp/tmpupper/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.14184755.

# %%
print(model.evaluate(input_fn=test_input_fn))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-07-11-02:04:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpupper/model.ckpt-1701
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-07-11-02:05:41
# INFO:tensorflow:Saving dict for global step 1701: accuracy = 0.90516603, global_step = 1701, loss = 0.29932573
# {'global_step': 1701, 'accuracy': 0.90516603, 'loss': 0.29932573}
