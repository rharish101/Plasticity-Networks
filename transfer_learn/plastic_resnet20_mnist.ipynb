# %%
from __future__ import print_function
import tensorflow as tf
import numpy as np
# Out:
# /usr/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
tf.logging.set_verbosity(tf.logging.INFO)

# %%
SAVED_MODEL_PATH = "/mnt/Data/tmp/resnet/plastic_20" # Saved Plastic ResNet checkpoint
TO_SAVE_PATH = SAVED_MODEL_PATH + "/mnist" # Where to save current model
BATCH_SIZE = 32
EPOCHS = 200
LEARN_RATE = 5e-5

# %%
def train_input_fn(mnist):
    train_dataset = tf.data.Dataset.from_tensor_slices((mnist.train.images,
                                                        mnist.train.labels))

    map_fn = lambda img, lbl: (tf.image.resize_images(tf.reshape(img, [28, 28, 1]),
                                                      (32, 32)), lbl)
    train_dataset = train_dataset.map(map_fn).shuffle(10000).apply(
        tf.contrib.data.batch_and_drop_remainder(BATCH_SIZE))

    return train_dataset

# %%
def test_input_fn(mnist):
    test_dataset = tf.data.Dataset.from_tensor_slices((mnist.test.images,
                                                       mnist.test.labels))

    map_fn = lambda img, lbl: (tf.image.resize_images(tf.reshape(img, [28, 28, 1]),
                                                      (32, 32)), lbl)
    test_dataset = test_dataset.map(map_fn).shuffle(10000).apply(
        tf.contrib.data.batch_and_drop_remainder(BATCH_SIZE))

    return test_dataset

# %%
mnist = tf.contrib.learn.datasets.load_dataset('mnist')
# Out:
# WARNING:tensorflow:From <ipython-input-6-c473456d8aca>:1: load_dataset (from tensorflow.contrib.learn.python.learn.datasets) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data.
# WARNING:tensorflow:From /usr/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/__init__.py:80: load_mnist (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:300: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST-data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /usr/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST-data/train-labels-idx1-ubyte.gz
# Extracting MNIST-data/t10k-images-idx3-ubyte.gz
# Extracting MNIST-data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
def resnet_layer(inputs, eta, scope_name, filters=16, kernel_size=3, strides=1,
                 activation=tf.nn.relu, batch_normalization=True, trainable=False):
    # Function from keras's example for Cifar10:
    # https://github.com/keras-team/keras/blob/master/examples/cifar10_resnet.py
    #x = tf.layers.conv2d(inputs=inputs, filters=filters, kernel_size=kernel_size,
    #                     strides=strides, padding='same')
    with tf.variable_scope(scope_name):
        w = tf.get_variable('conv_w', (kernel_size, kernel_size,
            int(inputs.shape[-1]), filters), trainable=trainable)
        alpha = tf.get_variable('conv_alpha', (kernel_size, kernel_size,
            int(inputs.shape[-1]), filters), trainable=trainable)
        hebb = tf.get_variable('conv_hebb', (kernel_size, kernel_size,
            int(inputs.shape[-1]), filters), trainable=False,
            initializer=tf.zeros_initializer)
        b = tf.get_variable('conv_b', (filters,), trainable=trainable)
    
    x = tf.nn.conv2d(input=inputs, filter=w + tf.multiply(alpha, hebb),
                     strides=[1, strides, strides, 1], padding='SAME') + b
    
    if trainable:
        # y is to be the output reshaped so as to be used as a kernel for convolution
        #     on input to get Hebbian update
        y = tf.image.resize_images(x, [int(inputs.shape[1])] * 2)
        y = tf.transpose(y, [1, 2, 0, 3])

        # in_mod is the input padded a/c to prev. convolution
        in_mod = tf.pad(inputs, [[0, 0], *([[int(np.floor((kernel_size - 1) / 2)),
                int(np.ceil((kernel_size - 1) / 2))]] * 2), [0, 0]])
        # in_mod is now modded so as to preserve channels and sum over mini-batch
        #     samples for Hebbian update convolution
        in_mod = tf.transpose(in_mod, [3, 1, 2, 0])

        hebb_update = tf.nn.conv2d(input=in_mod, filter=y, strides=([1] * 4),
                                   padding='VALID')
        hebb = eta * tf.transpose(hebb_update, [1, 2, 0, 3]) + (1 - eta) * hebb
    
    if batch_normalization:
        x = tf.layers.batch_normalization(x, trainable=trainable)
    if activation is not None:
        x = activation(x)
    return x

# %%
def resnet_model(features, labels, mode):
    # Function from keras's example for Cifar10:
    # https://github.com/keras-team/keras/blob/master/examples/cifar10_resnet.py
    filters = 16
    num_res_blocks = 3
    eta = tf.get_variable('Variable', [1,], trainable=False,
                          initializer=tf.truncated_normal_initializer)
    
    features = tf.cast(features, dtype=tf.float32)
    x = resnet_layer(inputs=features, eta=eta, scope_name='first', trainable=True)
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:
                strides = 2
            y = resnet_layer(inputs=x, eta=eta, scope_name="{}_{}_one".format(
                stack, res_block), filters=filters, strides=strides,
                trainable=True)
            y = resnet_layer(inputs=y, eta=eta, scope_name="{}_{}_two".format(
                stack, res_block), filters=filters, activation=None,
                trainable=True)
            if stack > 0 and res_block == 0:
                x = resnet_layer(inputs=x, eta=eta, scope_name="{}_{}_three".format(
                    stack, res_block), filters=filters, kernel_size=1,
                    strides=strides, activation=None, batch_normalization=False,
                    trainable=True)
            x = tf.nn.relu(x + y)
        filters *= 2
    
    x = tf.layers.average_pooling2d(x, pool_size=8, strides=8)
    x = tf.layers.flatten(x)
    
    #x = tf.layers.dense(inputs=x, units=10)
    w = tf.get_variable('Variable_1', (int(x.shape[1]), 10),
                        initializer=tf.truncated_normal_initializer)
    alpha = tf.get_variable('Variable_2', (int(x.shape[1]), 10),
                           initializer=tf.truncated_normal_initializer)
    hebb = tf.get_variable('Variable_3', (int(x.shape[1]), 10),
                           trainable=False, initializer=tf.zeros_initializer)
    
    b = tf.get_variable('Variable_4', (10,),
                        initializer=tf.truncated_normal_initializer)
    y = tf.matmul(x, w + tf.multiply(alpha, hebb)) + b
    hebb = eta * tf.reduce_mean(tf.matmul(tf.expand_dims(x, axis=-1),
        tf.expand_dims(y, axis=1)), axis=0) + (1 - eta) * hebb
    x = y
    
    classes = tf.argmax(input=x, axis=1)
    correct_prediction = tf.equal(tf.cast(classes, tf.uint8), labels)
    acc = tf.reduce_mean(tf.cast(correct_prediction, tf.float32)) * 100
    acc = tf.identity(acc, name='accuracy_tensor')
    
    predictions = {'classes': classes, 'accuracy': acc}
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)
        
    onehot_labels = tf.one_hot(tf.cast(labels, tf.int32), 10)
    loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=onehot_labels, logits=x)
    loss = tf.reduce_mean(loss)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.contrib.estimator.TowerOptimizer(tf.train.AdamOptimizer(
            LEARN_RATE))
        train_op = optimizer.minimize(loss=loss,
                                      global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

    eval_metric_ops = {'accuracy': tf.metrics.accuracy(labels=labels,
                                                       predictions=classes)}
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss,
                                      eval_metric_ops=eval_metric_ops)

# %%
tensors_to_log = {'accuracy': 'accuracy_tensor'}
logging_hook = tf.train.LoggingTensorHook(tensors=tensors_to_log, every_n_iter=100)

# %%
vars_warm = []
for var in ('alpha', 'b', 'hebb', 'w'):
    for stack in range(3):
        for res_block in range(3):
            for layer in ('one', 'two'):
                vars_warm.append("{}_{}_{}/conv_{}".format(stack, res_block, layer,
                                                           var))
            if stack > 0 and res_block == 0:
                vars_warm.append("{}_{}_three/conv_{}".format(stack, res_block,
                                                              var))
    vars_warm.append("first/conv_{}".format(var))
for var in ('beta', 'gamma', 'moving_mean', 'moving_variance'):
    vars_warm.append("batch_normalization/{}".format(var))
    for num in range(1, 19):
        vars_warm.append("batch_normalization_{}/{}".format(num, var))
vars_warm.append("Variable")
#for num in range(1, 5):
    #vars_warm.append("Variable_{}".format(num))
vars_warm += ['beta1_power', 'beta2_power']

# %%
warm_start = tf.estimator.WarmStartSettings(
    ckpt_to_initialize_from=SAVED_MODEL_PATH, vars_to_warm_start=vars_warm)

# %%
model = tf.estimator.Estimator(model_fn=tf.contrib.estimator.replicate_model_fn(
    resnet_model), model_dir=TO_SAVE_PATH, warm_start_from=warm_start)
# Out:
# WARNING:tensorflow:From <ipython-input-12-a425ed593574>:2: replicate_model_fn (from tensorflow.contrib.estimator.python.estimator.replicate_model_fn) is deprecated and will be removed after 2018-05-31.
# Instructions for updating:
# Please use `tf.contrib.distribute.MirroredStrategy` instead.
# INFO:tensorflow:Replicating the `model_fn` across ['/device:GPU:0'].  Variables are going to be placed on ['/device:GPU:0'].  Consolidation device is going to be /device:GPU:0.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/mnt/Data/tmp/resnet/plastic_20/mnist', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f3ab38aa358>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function _replicate_model_fn_with_mode.<locals>.single_device_model_fn at 0x7f3ab38ae510>) includes params argument, but params are not passed to Estimator.

# %%
max_steps = int((mnist.train.images.shape[0] / BATCH_SIZE) * EPOCHS)
model.train(input_fn=lambda:train_input_fn(mnist), hooks=[logging_hook],
            max_steps=max_steps)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/mnt/Data/tmp/resnet/plastic_20', vars_to_warm_start=['0_0_one/conv_alpha', '0_0_two/conv_alpha', '0_1_one/conv_alpha', '0_1_two/conv_alpha', '0_2_one/conv_alpha', '0_2_two/conv_alpha', '1_0_one/conv_alpha', '1_0_two/conv_alpha', '1_0_three/conv_alpha', '1_1_one/conv_alpha', '1_1_two/conv_alpha', '1_2_one/conv_alpha', '1_2_two/conv_alpha', '2_0_one/conv_alpha', '2_0_two/conv_alpha', '2_0_three/conv_alpha', '2_1_one/conv_alpha', '2_1_two/conv_alpha', '2_2_one/conv_alpha', '2_2_two/conv_alpha', 'first/conv_alpha', '0_0_one/conv_b', '0_0_two/conv_b', '0_1_one/conv_b', '0_1_two/conv_b', '0_2_one/conv_b', '0_2_two/conv_b', '1_0_one/conv_b', '1_0_two/conv_b', '1_0_three/conv_b', '1_1_one/conv_b', '1_1_two/conv_b', '1_2_one/conv_b', '1_2_two/conv_b', '2_0_one/conv_b', '2_0_two/conv_b', '2_0_three/conv_b', '2_1_one/conv_b', '2_1_two/conv_b', '2_2_one/conv_b', '2_2_two/conv_b', 'first/conv_b', '0_0_one/conv_hebb', '0_0_two/conv_hebb', '0_1_one/conv_hebb', '0_1_two/conv_hebb', '0_2_one/conv_hebb', '0_2_two/conv_hebb', '1_0_one/conv_hebb', '1_0_two/conv_hebb', '1_0_three/conv_hebb', '1_1_one/conv_hebb', '1_1_two/conv_hebb', '1_2_one/conv_hebb', '1_2_two/conv_hebb', '2_0_one/conv_hebb', '2_0_two/conv_hebb', '2_0_three/conv_hebb', '2_1_one/conv_hebb', '2_1_two/conv_hebb', '2_2_one/conv_hebb', '2_2_two/conv_hebb', 'first/conv_hebb', '0_0_one/conv_w', '0_0_two/conv_w', '0_1_one/conv_w', '0_1_two/conv_w', '0_2_one/conv_w', '0_2_two/conv_w', '1_0_one/conv_w', '1_0_two/conv_w', '1_0_three/conv_w', '1_1_one/conv_w', '1_1_two/conv_w', '1_2_one/conv_w', '1_2_two/conv_w', '2_0_one/conv_w', '2_0_two/conv_w', '2_0_three/conv_w', '2_1_one/conv_w', '2_1_two/conv_w', '2_2_one/conv_w', '2_2_two/conv_w', 'first/conv_w', 'batch_normalization/beta', 'batch_normalization_1/beta', 'batch_normalization_2/beta', 'batch_normalization_3/beta', 'batch_normalization_4/beta', 'batch_normalization_5/beta', 'batch_normalization_6/beta', 'batch_normalization_7/beta', 'batch_normalization_8/beta', 'batch_normalization_9/beta', 'batch_normalization_10/beta', 'batch_normalization_11/beta', 'batch_normalization_12/beta', 'batch_normalization_13/beta', 'batch_normalization_14/beta', 'batch_normalization_15/beta', 'batch_normalization_16/beta', 'batch_normalization_17/beta', 'batch_normalization_18/beta', 'batch_normalization/gamma', 'batch_normalization_1/gamma', 'batch_normalization_2/gamma', 'batch_normalization_3/gamma', 'batch_normalization_4/gamma', 'batch_normalization_5/gamma', 'batch_normalization_6/gamma', 'batch_normalization_7/gamma', 'batch_normalization_8/gamma', 'batch_normalization_9/gamma', 'batch_normalization_10/gamma', 'batch_normalization_11/gamma', 'batch_normalization_12/gamma', 'batch_normalization_13/gamma', 'batch_normalization_14/gamma', 'batch_normalization_15/gamma', 'batch_normalization_16/gamma', 'batch_normalization_17/gamma', 'batch_normalization_18/gamma', 'batch_normalization/moving_mean', 'batch_normalization_1/moving_mean', 'batch_normalization_2/moving_mean', 'batch_normalization_3/moving_mean', 'batch_normalization_4/moving_mean', 'batch_normalization_5/moving_mean', 'batch_normalization_6/moving_mean', 'batch_normalization_7/moving_mean', 'batch_normalization_8/moving_mean', 'batch_normalization_9/moving_mean', 'batch_normalization_10/moving_mean', 'batch_normalization_11/moving_mean', 'batch_normalization_12/moving_mean', 'batch_normalization_13/moving_mean', 'batch_normalization_14/moving_mean', 'batch_normalization_15/moving_mean', 'batch_normalization_16/moving_mean', 'batch_normalization_17/moving_mean', 'batch_normalization_18/moving_mean', 'batch_normalization/moving_variance', 'batch_normalization_1/moving_variance', 'batch_normalization_2/moving_variance', 'batch_normalization_3/moving_variance', 'batch_normalization_4/moving_variance', 'batch_normalization_5/moving_variance', 'batch_normalization_6/moving_variance', 'batch_normali ...
# INFO:tensorflow:Warm-starting from: ('/mnt/Data/tmp/resnet/plastic_20',)
# INFO:tensorflow:Warm-starting variable: 0_0_one/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_one/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_one/conv_alpha
# INFO:tensorflow:Warm-starting variable: 0_0_one/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_one/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_one/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 0_0_one/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_one/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_one/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_0_two/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_two/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_two/conv_alpha
# INFO:tensorflow:Warm-starting variable: 0_0_two/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_two/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_two/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 0_0_two/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_two/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_two/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_1_one/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_one/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_one/conv_alpha
# INFO:tensorflow:Warm-starting variable: 0_1_one/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_one/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_one/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 0_1_one/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_one/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_one/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_1_two/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_two/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_two/conv_alpha
# INFO:tensorflow:Warm-starting variable: 0_1_two/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_two/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_two/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 0_1_two/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_two/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_two/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_2_one/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_one/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_one/conv_alpha
# INFO:tensorflow:Warm-starting variable: 0_2_one/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_one/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_one/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 0_2_one/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_one/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_one/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_2_two/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_two/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_two/conv_alpha
# INFO:tensorflow:Warm-starting variable: 0_2_two/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_two/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_two/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 0_2_two/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_two/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_two/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_0_one/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_one/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_one/conv_alpha
# INFO:tensorflow:Warm-starting variable: 1_0_one/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_one/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_one/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 1_0_one/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_one/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_one/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_0_two/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_two/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_two/conv_alpha
# INFO:tensorflow:Warm-starting variable: 1_0_two/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_two/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_two/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 1_0_two/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_two/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_two/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_0_three/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_three/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_three/conv_alpha
# INFO:tensorflow:Warm-starting variable: 1_0_three/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_three/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_three/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 1_0_three/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_three/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_three/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_1_one/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_one/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_one/conv_alpha
# INFO:tensorflow:Warm-starting variable: 1_1_one/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_one/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_one/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 1_1_one/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_one/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_one/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_1_two/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_two/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_two/conv_alpha
# INFO:tensorflow:Warm-starting variable: 1_1_two/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_two/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_two/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 1_1_two/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_two/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_two/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_2_one/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_one/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_one/conv_alpha
# INFO:tensorflow:Warm-starting variable: 1_2_one/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_one/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_one/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 1_2_one/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_one/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_one/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_2_two/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_two/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_two/conv_alpha
# INFO:tensorflow:Warm-starting variable: 1_2_two/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_two/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_two/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 1_2_two/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_two/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_two/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_0_one/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_one/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_one/conv_alpha
# INFO:tensorflow:Warm-starting variable: 2_0_one/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_one/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_one/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 2_0_one/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_one/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_one/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_0_two/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_two/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_two/conv_alpha
# INFO:tensorflow:Warm-starting variable: 2_0_two/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_two/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_two/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 2_0_two/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_two/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_two/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_0_three/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_three/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_three/conv_alpha
# INFO:tensorflow:Warm-starting variable: 2_0_three/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_three/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_three/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 2_0_three/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_three/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_three/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_1_one/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_one/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_one/conv_alpha
# INFO:tensorflow:Warm-starting variable: 2_1_one/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_one/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_one/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 2_1_one/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_one/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_one/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_1_two/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_two/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_two/conv_alpha
# INFO:tensorflow:Warm-starting variable: 2_1_two/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_two/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_two/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 2_1_two/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_two/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_two/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_2_one/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_2_one/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_2_one/conv_alpha
# INFO:tensorflow:Warm-starting variable: 2_2_one/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_2_one/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_2_one/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 2_2_one/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_2_one/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_2_one/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_2_two/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_2_two/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_2_two/conv_alpha
# INFO:tensorflow:Warm-starting variable: 2_2_two/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_2_two/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_2_two/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: 2_2_two/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_2_two/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_2_two/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: first/conv_alpha; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable first/conv_alpha:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with first/conv_alpha
# INFO:tensorflow:Warm-starting variable: first/conv_alpha/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable first/conv_alpha/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with first/conv_alpha/Adam
# INFO:tensorflow:Warm-starting variable: first/conv_alpha/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable first/conv_alpha/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with first/conv_alpha/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_0_one/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_one/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_one/conv_b
# INFO:tensorflow:Warm-starting variable: 0_0_one/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_one/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_one/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 0_0_one/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_one/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_one/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_0_two/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_two/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_two/conv_b
# INFO:tensorflow:Warm-starting variable: 0_0_two/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_two/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_two/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 0_0_two/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_two/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_two/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_1_one/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_one/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_one/conv_b
# INFO:tensorflow:Warm-starting variable: 0_1_one/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_one/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_one/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 0_1_one/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_one/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_one/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_1_two/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_two/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_two/conv_b
# INFO:tensorflow:Warm-starting variable: 0_1_two/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_two/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_two/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 0_1_two/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_two/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_two/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_2_one/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_one/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_one/conv_b
# INFO:tensorflow:Warm-starting variable: 0_2_one/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_one/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_one/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 0_2_one/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_one/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_one/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_2_two/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_two/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_two/conv_b
# INFO:tensorflow:Warm-starting variable: 0_2_two/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_two/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_two/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 0_2_two/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_two/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_two/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_0_one/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_one/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_one/conv_b
# INFO:tensorflow:Warm-starting variable: 1_0_one/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_one/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_one/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 1_0_one/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_one/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_one/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_0_two/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_two/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_two/conv_b
# INFO:tensorflow:Warm-starting variable: 1_0_two/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_two/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_two/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 1_0_two/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_two/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_two/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_0_three/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_three/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_three/conv_b
# INFO:tensorflow:Warm-starting variable: 1_0_three/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_three/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_three/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 1_0_three/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_three/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_three/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_1_one/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_one/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_one/conv_b
# INFO:tensorflow:Warm-starting variable: 1_1_one/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_one/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_one/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 1_1_one/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_one/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_one/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_1_two/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_two/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_two/conv_b
# INFO:tensorflow:Warm-starting variable: 1_1_two/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_two/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_two/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 1_1_two/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_two/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_two/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_2_one/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_one/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_one/conv_b
# INFO:tensorflow:Warm-starting variable: 1_2_one/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_one/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_one/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 1_2_one/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_one/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_one/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_2_two/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_two/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_two/conv_b
# INFO:tensorflow:Warm-starting variable: 1_2_two/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_two/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_two/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 1_2_two/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_two/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_two/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_0_one/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_one/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_one/conv_b
# INFO:tensorflow:Warm-starting variable: 2_0_one/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_one/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_one/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 2_0_one/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_one/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_one/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_0_two/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_two/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_two/conv_b
# INFO:tensorflow:Warm-starting variable: 2_0_two/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_two/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_two/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 2_0_two/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_two/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_two/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_0_three/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_three/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_three/conv_b
# INFO:tensorflow:Warm-starting variable: 2_0_three/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_three/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_three/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 2_0_three/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_three/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_three/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_1_one/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_one/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_one/conv_b
# INFO:tensorflow:Warm-starting variable: 2_1_one/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_one/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_one/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 2_1_one/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_one/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_one/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_1_two/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_two/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_two/conv_b
# INFO:tensorflow:Warm-starting variable: 2_1_two/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_two/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_two/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 2_1_two/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_two/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_two/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_2_one/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_2_one/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_2_one/conv_b
# INFO:tensorflow:Warm-starting variable: 2_2_one/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_2_one/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_2_one/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 2_2_one/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_2_one/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_2_one/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_2_two/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_2_two/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_2_two/conv_b
# INFO:tensorflow:Warm-starting variable: 2_2_two/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_2_two/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_2_two/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: 2_2_two/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_2_two/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_2_two/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: first/conv_b; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable first/conv_b:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with first/conv_b
# INFO:tensorflow:Warm-starting variable: first/conv_b/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable first/conv_b/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with first/conv_b/Adam
# INFO:tensorflow:Warm-starting variable: first/conv_b/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable first/conv_b/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with first/conv_b/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_0_one/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_one/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_one/conv_hebb
# INFO:tensorflow:Warm-starting variable: 0_0_two/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_two/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_two/conv_hebb
# INFO:tensorflow:Warm-starting variable: 0_1_one/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_one/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_one/conv_hebb
# INFO:tensorflow:Warm-starting variable: 0_1_two/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_two/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_two/conv_hebb
# INFO:tensorflow:Warm-starting variable: 0_2_one/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_one/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_one/conv_hebb
# INFO:tensorflow:Warm-starting variable: 0_2_two/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_two/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_two/conv_hebb
# INFO:tensorflow:Warm-starting variable: 1_0_one/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_one/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_one/conv_hebb
# INFO:tensorflow:Warm-starting variable: 1_0_two/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_two/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_two/conv_hebb
# INFO:tensorflow:Warm-starting variable: 1_0_three/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_three/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_three/conv_hebb
# INFO:tensorflow:Warm-starting variable: 1_1_one/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_one/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_one/conv_hebb
# INFO:tensorflow:Warm-starting variable: 1_1_two/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_two/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_two/conv_hebb
# INFO:tensorflow:Warm-starting variable: 1_2_one/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_one/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_one/conv_hebb
# INFO:tensorflow:Warm-starting variable: 1_2_two/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_two/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_two/conv_hebb
# INFO:tensorflow:Warm-starting variable: 2_0_one/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_one/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_one/conv_hebb
# INFO:tensorflow:Warm-starting variable: 2_0_two/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_two/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_two/conv_hebb
# INFO:tensorflow:Warm-starting variable: 2_0_three/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_three/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_three/conv_hebb
# INFO:tensorflow:Warm-starting variable: 2_1_one/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_one/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_one/conv_hebb
# INFO:tensorflow:Warm-starting variable: 2_1_two/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_two/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_two/conv_hebb
# INFO:tensorflow:Warm-starting variable: 2_2_one/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_2_one/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_2_one/conv_hebb
# INFO:tensorflow:Warm-starting variable: 2_2_two/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_2_two/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_2_two/conv_hebb
# INFO:tensorflow:Warm-starting variable: first/conv_hebb; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable first/conv_hebb:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with first/conv_hebb
# INFO:tensorflow:Warm-starting variable: 0_0_one/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_one/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_one/conv_w
# INFO:tensorflow:Warm-starting variable: 0_0_one/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_one/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_one/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 0_0_one/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_one/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_one/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_0_two/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_two/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_two/conv_w
# INFO:tensorflow:Warm-starting variable: 0_0_two/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_two/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_two/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 0_0_two/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_0_two/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_0_two/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_1_one/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_one/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_one/conv_w
# INFO:tensorflow:Warm-starting variable: 0_1_one/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_one/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_one/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 0_1_one/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_one/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_one/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_1_two/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_two/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_two/conv_w
# INFO:tensorflow:Warm-starting variable: 0_1_two/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_two/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_two/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 0_1_two/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_1_two/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_1_two/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_2_one/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_one/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_one/conv_w
# INFO:tensorflow:Warm-starting variable: 0_2_one/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_one/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_one/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 0_2_one/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_one/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_one/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 0_2_two/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_two/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_two/conv_w
# INFO:tensorflow:Warm-starting variable: 0_2_two/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_two/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_two/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 0_2_two/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 0_2_two/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 0_2_two/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_0_one/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_one/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_one/conv_w
# INFO:tensorflow:Warm-starting variable: 1_0_one/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_one/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_one/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 1_0_one/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_one/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_one/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_0_two/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_two/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_two/conv_w
# INFO:tensorflow:Warm-starting variable: 1_0_two/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_two/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_two/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 1_0_two/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_two/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_two/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_0_three/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_three/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_three/conv_w
# INFO:tensorflow:Warm-starting variable: 1_0_three/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_three/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_three/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 1_0_three/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_0_three/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_0_three/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_1_one/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_one/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_one/conv_w
# INFO:tensorflow:Warm-starting variable: 1_1_one/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_one/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_one/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 1_1_one/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_one/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_one/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_1_two/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_two/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_two/conv_w
# INFO:tensorflow:Warm-starting variable: 1_1_two/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_two/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_two/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 1_1_two/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_1_two/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_1_two/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_2_one/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_one/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_one/conv_w
# INFO:tensorflow:Warm-starting variable: 1_2_one/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_one/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_one/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 1_2_one/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_one/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_one/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 1_2_two/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_two/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_two/conv_w
# INFO:tensorflow:Warm-starting variable: 1_2_two/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_two/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_two/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 1_2_two/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 1_2_two/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 1_2_two/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_0_one/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_one/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_one/conv_w
# INFO:tensorflow:Warm-starting variable: 2_0_one/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_one/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_one/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 2_0_one/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_one/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_one/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_0_two/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_two/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_two/conv_w
# INFO:tensorflow:Warm-starting variable: 2_0_two/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_two/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_two/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 2_0_two/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_two/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_two/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_0_three/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_three/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_three/conv_w
# INFO:tensorflow:Warm-starting variable: 2_0_three/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_three/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_three/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 2_0_three/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_0_three/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_0_three/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_1_one/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_one/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_one/conv_w
# INFO:tensorflow:Warm-starting variable: 2_1_one/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_one/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_one/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 2_1_one/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_one/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_one/conv_w/Adam_1
# INFO:tensorflow:Warm-starting variable: 2_1_two/conv_w; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_two/conv_w:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_two/conv_w
# INFO:tensorflow:Warm-starting variable: 2_1_two/conv_w/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_two/conv_w/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_two/conv_w/Adam
# INFO:tensorflow:Warm-starting variable: 2_1_two/conv_w/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable 2_1_two/conv_w/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with 2_1_two/conv_w/Adam_1
# ...
# INFO:tensorflow:Warm-starting variable: batch_normalization_18/gamma/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_18/gamma/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_18/gamma/Adam_1
# INFO:tensorflow:Warm-starting variable: batch_normalization/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_1/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_1/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_2/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_2/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_2/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_3/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_3/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_3/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_4/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_4/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_4/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_5/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_5/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_5/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_6/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_6/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_6/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_7/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_7/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_7/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_8/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_8/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_8/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_9/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_9/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_9/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_10/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_10/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_10/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_11/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_11/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_11/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_12/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_12/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_12/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_13/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_13/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_13/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_14/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_14/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_14/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_15/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_15/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_15/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_16/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_16/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_16/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_17/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_17/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_17/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization_18/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_18/moving_mean:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_18/moving_mean
# INFO:tensorflow:Warm-starting variable: batch_normalization/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_1/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_1/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_2/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_2/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_2/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_3/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_3/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_3/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_4/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_4/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_4/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_5/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_5/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_5/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_6/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_6/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_6/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_7/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_7/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_7/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_8/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_8/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_8/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_9/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_9/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_9/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_10/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_10/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_10/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_11/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_11/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_11/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_12/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_12/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_12/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_13/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_13/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_13/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_14/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_14/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_14/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_15/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_15/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_15/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_16/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_16/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_16/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_17/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_17/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_17/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_18/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_18/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with batch_normalization_18/moving_variance
# INFO:tensorflow:Warm-starting variable: Variable; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with Variable
# INFO:tensorflow:Warm-starting variable: Variable_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with Variable_1
# INFO:tensorflow:Warm-starting variable: Variable_2; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_2:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with Variable_2
# INFO:tensorflow:Warm-starting variable: Variable_3; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_3:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with Variable_3
# INFO:tensorflow:Warm-starting variable: Variable_4; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_4:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with Variable_4
# INFO:tensorflow:Warm-starting variable: Variable_1/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_1/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with Variable_1/Adam
# INFO:tensorflow:Warm-starting variable: Variable_1/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_1/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with Variable_1/Adam_1
# INFO:tensorflow:Warm-starting variable: Variable_2/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_2/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with Variable_2/Adam
# INFO:tensorflow:Warm-starting variable: Variable_2/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_2/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with Variable_2/Adam_1
# INFO:tensorflow:Warm-starting variable: Variable_4/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_4/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with Variable_4/Adam
# INFO:tensorflow:Warm-starting variable: Variable_4/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_4/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with Variable_4/Adam_1
# INFO:tensorflow:Warm-starting variable: beta1_power; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable beta1_power:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with beta1_power
# INFO:tensorflow:Warm-starting variable: beta2_power; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable beta2_power:0 from checkpoint /mnt/Data/tmp/resnet/plastic_20 with beta2_power
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /mnt/Data/tmp/resnet/plastic_20/mnist/model.ckpt.
# INFO:tensorflow:accuracy = 18.75
# INFO:tensorflow:loss = 2.6397486, step = 0
# INFO:tensorflow:global_step/sec: 10.0948
# INFO:tensorflow:accuracy = 40.625 (9.912 sec)
# INFO:tensorflow:loss = 2.0617504, step = 100 (9.912 sec)
# INFO:tensorflow:global_step/sec: 8.90752
# INFO:tensorflow:accuracy = 50.0 (11.222 sec)
# INFO:tensorflow:loss = 1.5468142, step = 200 (11.222 sec)
# INFO:tensorflow:global_step/sec: 7.5574
# INFO:tensorflow:accuracy = 87.5 (13.232 sec)
# INFO:tensorflow:loss = 0.6681226, step = 300 (13.232 sec)
# INFO:tensorflow:global_step/sec: 7.68205
# INFO:tensorflow:accuracy = 84.375 (13.017 sec)
# INFO:tensorflow:loss = 0.4435553, step = 400 (13.017 sec)
# INFO:tensorflow:global_step/sec: 7.66261
# INFO:tensorflow:accuracy = 93.75 (13.050 sec)
# INFO:tensorflow:loss = 0.2970332, step = 500 (13.050 sec)
# INFO:tensorflow:global_step/sec: 7.60102
# INFO:tensorflow:accuracy = 81.25 (13.156 sec)
# INFO:tensorflow:loss = 0.4785569, step = 600 (13.156 sec)
# INFO:tensorflow:global_step/sec: 7.65738
# INFO:tensorflow:accuracy = 93.75 (13.060 sec)
# INFO:tensorflow:loss = 0.2003256, step = 700 (13.061 sec)
# INFO:tensorflow:global_step/sec: 7.65338
# INFO:tensorflow:accuracy = 100.0 (13.067 sec)
# INFO:tensorflow:loss = 0.04787628, step = 800 (13.066 sec)
# INFO:tensorflow:global_step/sec: 7.29096
# INFO:tensorflow:accuracy = 100.0 (13.716 sec)
# INFO:tensorflow:loss = 0.035060987, step = 900 (13.716 sec)
# INFO:tensorflow:global_step/sec: 7.09215
# INFO:tensorflow:accuracy = 93.75 (14.100 sec)
# INFO:tensorflow:loss = 0.11129532, step = 1000 (14.100 sec)
# INFO:tensorflow:global_step/sec: 7.16345
# INFO:tensorflow:accuracy = 93.75 (13.959 sec)
# INFO:tensorflow:loss = 0.131646, step = 1100 (13.958 sec)
# INFO:tensorflow:global_step/sec: 7.00193
# INFO:tensorflow:accuracy = 100.0 (14.283 sec)
# INFO:tensorflow:loss = 0.050531685, step = 1200 (14.283 sec)
# INFO:tensorflow:global_step/sec: 6.89551
# INFO:tensorflow:accuracy = 96.875 (14.501 sec)
# INFO:tensorflow:loss = 0.111100934, step = 1300 (14.502 sec)
# INFO:tensorflow:global_step/sec: 6.83028
# INFO:tensorflow:accuracy = 93.75 (14.641 sec)
# INFO:tensorflow:loss = 0.25226125, step = 1400 (14.639 sec)
# INFO:tensorflow:global_step/sec: 6.78056
# INFO:tensorflow:accuracy = 96.875 (14.750 sec)
# INFO:tensorflow:loss = 0.16076821, step = 1500 (14.751 sec)
# INFO:tensorflow:global_step/sec: 6.69251
# INFO:tensorflow:accuracy = 96.875 (14.940 sec)
# INFO:tensorflow:loss = 0.09382269, step = 1600 (14.940 sec)
# INFO:tensorflow:global_step/sec: 6.68886
# INFO:tensorflow:accuracy = 93.75 (14.950 sec)
# INFO:tensorflow:loss = 0.11602848, step = 1700 (14.950 sec)
# INFO:tensorflow:Saving checkpoints for 1718 into /mnt/Data/tmp/resnet/plastic_20/mnist/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.12276631.

# %%
print(model.evaluate(input_fn=lambda:test_input_fn(mnist)))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-29-07:06:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /mnt/Data/tmp/resnet/plastic_20/mnist/model.ckpt-1718
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-06-29-07:06:59
# INFO:tensorflow:Saving dict for global step 1718: accuracy = 0.9666466, global_step = 1718, loss = 0.106023505
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1718: /mnt/Data/tmp/resnet/plastic_20/mnist/model.ckpt-1718
# {'accuracy': 0.9666466, 'loss': 0.106023505, 'global_step': 1718}
