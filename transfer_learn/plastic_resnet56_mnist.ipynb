# %%
from __future__ import print_function
import tensorflow as tf
import numpy as np

# %%
tf.logging.set_verbosity(tf.logging.INFO)

# %%
SAVED_MODEL_PATH = "/mnt/Data/tmp/resnet/plastic_56" # Saved Plastic ResNet checkpoint
TO_SAVE_PATH = SAVED_MODEL_PATH + "/mnist" # Where to save current model
BATCH_SIZE = 32
EPOCHS = 200
LEARN_RATE = 5e-4

# %%
def train_input_fn(mnist):
    train_dataset = tf.data.Dataset.from_tensor_slices((mnist.train.images,
                                                        mnist.train.labels))

    map_fn = lambda img, lbl: (tf.image.resize_images(tf.reshape(img, [28, 28, 1]),
                                                      (32, 32)), lbl)
    train_dataset = train_dataset.map(map_fn).shuffle(10000).apply(
        tf.contrib.data.batch_and_drop_remainder(BATCH_SIZE))

    return train_dataset

# %%
def test_input_fn(mnist):
    test_dataset = tf.data.Dataset.from_tensor_slices((mnist.test.images,
                                                       mnist.test.labels))

    map_fn = lambda img, lbl: (tf.image.resize_images(tf.reshape(img, [28, 28, 1]),
                                                      (32, 32)), lbl)
    test_dataset = test_dataset.map(map_fn).shuffle(10000).apply(
        tf.contrib.data.batch_and_drop_remainder(BATCH_SIZE))

    return test_dataset

# %%
mnist = tf.contrib.learn.datasets.load_dataset('mnist')
# Out:
# Extracting MNIST-data/train-images-idx3-ubyte.gz
# Extracting MNIST-data/train-labels-idx1-ubyte.gz
# Extracting MNIST-data/t10k-images-idx3-ubyte.gz
# Extracting MNIST-data/t10k-labels-idx1-ubyte.gz

# %%
def resnet_layer(inputs, eta, scope_name, filters=16, kernel_size=3, strides=1,
                 activation=tf.nn.relu, batch_normalization=True, trainable=False):
    # Function from keras's example for Cifar10:
    # https://github.com/keras-team/keras/blob/master/examples/cifar10_resnet.py
    #x = tf.layers.conv2d(inputs=inputs, filters=filters, kernel_size=kernel_size,
    #                     strides=strides, padding='same')
    with tf.variable_scope(scope_name):
        w = tf.get_variable('conv_w', (kernel_size, kernel_size,
            int(inputs.shape[-1]), filters), trainable=trainable)
        alpha = tf.get_variable('conv_alpha', (kernel_size, kernel_size,
            int(inputs.shape[-1]), filters), trainable=trainable)
        hebb = tf.get_variable('conv_hebb', (kernel_size, kernel_size,
            int(inputs.shape[-1]), filters), trainable=False,
            initializer=tf.zeros_initializer)
        b = tf.get_variable('conv_b', (filters,), trainable=trainable)
    
    x = tf.nn.conv2d(input=inputs, filter=w + tf.multiply(alpha, hebb),
                     strides=[1, strides, strides, 1], padding='SAME') + b
    
    # y is to be the output reshaped so as to be used as a kernel for convolution
    #     on input to get Hebbian update
    y = tf.image.resize_images(x, [int(inputs.shape[1])] * 2)
    y = tf.transpose(y, [1, 2, 0, 3])
    
    # in_mod is the input padded a/c to prev. convolution
    in_mod = tf.pad(inputs, [[0, 0], *([[int(np.floor((kernel_size - 1) / 2)),
            int(np.ceil((kernel_size - 1) / 2))]] * 2), [0, 0]])
    # in_mod is now modded so as to preserve channels and sum over mini-batch
    #     samples for Hebbian update convolution
    in_mod = tf.transpose(in_mod, [3, 1, 2, 0])
    
    hebb_update = tf.nn.conv2d(input=in_mod, filter=y, strides=([1] * 4),
                               padding='VALID')
    hebb = eta * tf.transpose(hebb_update, [1, 2, 0, 3]) + (1 - eta) * hebb
    
    if batch_normalization:
        x = tf.layers.batch_normalization(x, trainable=trainable)
    if activation is not None:
        x = activation(x)
    return x

# %%
def resnet_model(features, labels, mode):
    # Function from keras's example for Cifar10:
    # https://github.com/keras-team/keras/blob/master/examples/cifar10_resnet.py
    filters = 16
    num_res_blocks = 9
    eta = tf.get_variable('Variable', [1,], trainable=False,
                          initializer=tf.truncated_normal_initializer)
    
    features = tf.cast(features, dtype=tf.float32)
    x = resnet_layer(inputs=features, eta=eta, scope_name='first')
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:
                strides = 2
            y = resnet_layer(inputs=x, eta=eta, scope_name="{}_{}_one".format(
                stack, res_block), filters=filters, strides=strides,
                trainable=(stack == 2 and res_block > 4))
            y = resnet_layer(inputs=y, eta=eta, scope_name="{}_{}_two".format(
                stack, res_block), filters=filters, activation=None,
                trainable=(stack == 2 and res_block > 4))
            if stack > 0 and res_block == 0:
                x = resnet_layer(inputs=x, eta=eta, scope_name="{}_{}_three".format(
                    stack, res_block), filters=filters, kernel_size=1,
                    strides=strides, activation=None, batch_normalization=False,
                    trainable=(stack == 2 and res_block > 4))
            x = tf.nn.relu(x + y)
        filters *= 2
    
    x = tf.layers.average_pooling2d(x, pool_size=8, strides=8)
    x = tf.layers.flatten(x)
    
    #x = tf.layers.dense(inputs=x, units=10)
    w = tf.get_variable('Variable_1', (int(x.shape[1]), 10),
                        initializer=tf.truncated_normal_initializer)
    alpha = tf.get_variable('Variable_2', (int(x.shape[1]), 10),
                           initializer=tf.truncated_normal_initializer)
    hebb = tf.get_variable('Variable_3', (int(x.shape[1]), 10),
                           trainable=False, initializer=tf.zeros_initializer)
    
    b = tf.get_variable('Variable_4', (10,),
                        initializer=tf.truncated_normal_initializer)
    y = tf.matmul(x, w + tf.multiply(alpha, hebb)) + b
    hebb = eta * tf.reduce_mean(tf.matmul(tf.expand_dims(x, axis=-1),
        tf.expand_dims(y, axis=1)), axis=0) + (1 - eta) * hebb
    x = y
    
    classes = tf.argmax(input=x, axis=1)
    correct_prediction = tf.equal(tf.cast(classes, tf.uint8), labels)
    acc = tf.reduce_mean(tf.cast(correct_prediction, tf.float32)) * 100
    acc = tf.identity(acc, name='accuracy_tensor')
    
    predictions = {'classes': classes, 'accuracy': acc}
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)
        
    onehot_labels = tf.one_hot(tf.cast(labels, tf.int32), 10)
    loss = tf.nn.softmax_cross_entropy_with_logits_v2(labels=onehot_labels, logits=x)
    loss = tf.reduce_mean(loss)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.contrib.estimator.TowerOptimizer(tf.train.AdamOptimizer(
            LEARN_RATE))
        train_op = optimizer.minimize(loss=loss,
                                      global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

    eval_metric_ops = {'accuracy': tf.metrics.accuracy(labels=labels,
                                                       predictions=classes)}
    return tf.estimator.EstimatorSpec(mode=mode, loss=loss,
                                      eval_metric_ops=eval_metric_ops)

# %%
tensors_to_log = {'accuracy': 'accuracy_tensor'}
logging_hook = tf.train.LoggingTensorHook(tensors=tensors_to_log, every_n_iter=100)

# %%
vars_warm = []
for var in ('alpha', 'b', 'hebb', 'w'):
    for stack in range(3):
        for res_block in range(9):
            for layer in ('one', 'two'):
                vars_warm.append("{}_{}_{}/conv_{}".format(stack, res_block, layer,
                                                           var))
            if stack > 0 and res_block == 0:
                vars_warm.append("{}_{}_three/conv_{}".format(stack, res_block,
                                                              var))
    vars_warm.append("first/conv_{}".format(var))
for var in ('beta', 'gamma', 'moving_mean', 'moving_variance'):
    vars_warm.append("batch_normalization/{}".format(var))
    for num in range(1, 55):
        vars_warm.append("batch_normalization_{}/{}".format(num, var))
vars_warm.append("Variable")
#for num in range(1, 5):
    #vars_warm.append("Variable_{}".format(num))
vars_warm += ['beta1_power', 'beta2_power']

# %%
warm_start = tf.estimator.WarmStartSettings(
    ckpt_to_initialize_from=SAVED_MODEL_PATH, vars_to_warm_start=vars_warm)

# %%
model = tf.estimator.Estimator(model_fn=tf.contrib.estimator.replicate_model_fn(
    resnet_model), model_dir=TO_SAVE_PATH, warm_start_from=warm_start)
# Out:
# INFO:tensorflow:Replicating the `model_fn` across ['/device:GPU:0'].  Variables are going to be placed on ['/device:GPU:0'].  Consolidation device is going to be /device:GPU:0.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/mnt/Data/tmp/resnet/plastic_56/mnist', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fa4f2109d30>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function _replicate_model_fn_with_mode.<locals>.single_device_model_fn at 0x7fa4f91349d8>) includes params argument, but params are not passed to Estimator.

# %%
max_steps = int((mnist.train.images.shape[0] / BATCH_SIZE) * EPOCHS)
model.train(input_fn=lambda:train_input_fn(mnist), hooks=[logging_hook],
            max_steps=max_steps)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='/mnt/Data/tmp/resnet/plastic_56', vars_to_warm_start=['0_0_one/conv_alpha', '0_0_two/conv_alpha', '0_1_one/conv_alpha', '0_1_two/conv_alpha', '0_2_one/conv_alpha', '0_2_two/conv_alpha', '0_3_one/conv_alpha', '0_3_two/conv_alpha', '0_4_one/conv_alpha', '0_4_two/conv_alpha', '0_5_one/conv_alpha', '0_5_two/conv_alpha', '0_6_one/conv_alpha', '0_6_two/conv_alpha', '0_7_one/conv_alpha', '0_7_two/conv_alpha', '0_8_one/conv_alpha', '0_8_two/conv_alpha', '1_0_one/conv_alpha', '1_0_two/conv_alpha', '1_0_three/conv_alpha', '1_1_one/conv_alpha', '1_1_two/conv_alpha', '1_2_one/conv_alpha', '1_2_two/conv_alpha', '1_3_one/conv_alpha', '1_3_two/conv_alpha', '1_4_one/conv_alpha', '1_4_two/conv_alpha', '1_5_one/conv_alpha', '1_5_two/conv_alpha', '1_6_one/conv_alpha', '1_6_two/conv_alpha', '1_7_one/conv_alpha', '1_7_two/conv_alpha', '1_8_one/conv_alpha', '1_8_two/conv_alpha', '2_0_one/conv_alpha', '2_0_two/conv_alpha', '2_0_three/conv_alpha', '2_1_one/conv_alpha', '2_1_two/conv_al
moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_17/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_17/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_18/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_18/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_18/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_19/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_19/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_19/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_20/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_20/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_20/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_21/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_21/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_21/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_22/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_22/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_22/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_23/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_23/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_23/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_24/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_24/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_24/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_25/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_25/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_25/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_26/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_26/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_26/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_27/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_27/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_27/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_28/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_28/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_28/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_29/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_29/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_29/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_30/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_30/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_30/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_31/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_31/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_31/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_32/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_32/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_32/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_33/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_33/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_33/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_34/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_34/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_34/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_35/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_35/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_35/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_36/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_36/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_36/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_37/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_37/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_37/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_38/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_38/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_38/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_39/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_39/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_39/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_40/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_40/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_40/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_41/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_41/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_41/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_42/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_42/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_42/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_43/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_43/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_43/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_44/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_44/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_44/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_45/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_45/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_45/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_46/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_46/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_46/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_47/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_47/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_47/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_48/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_48/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_48/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_49/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_49/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_49/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_50/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_50/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_50/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_51/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_51/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_51/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_52/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_52/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_52/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_53/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_53/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_53/moving_variance
# INFO:tensorflow:Warm-starting variable: batch_normalization_54/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable batch_normalization_54/moving_variance:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with batch_normalization_54/moving_variance
# INFO:tensorflow:Warm-starting variable: Variable; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with Variable
# INFO:tensorflow:Warm-starting variable: Variable_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with Variable_1
# INFO:tensorflow:Warm-starting variable: Variable_2; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_2:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with Variable_2
# INFO:tensorflow:Warm-starting variable: Variable_3; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_3:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with Variable_3
# INFO:tensorflow:Warm-starting variable: Variable_4; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_4:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with Variable_4
# INFO:tensorflow:Warm-starting variable: Variable_1/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_1/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with Variable_1/Adam
# INFO:tensorflow:Warm-starting variable: Variable_1/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_1/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with Variable_1/Adam_1
# INFO:tensorflow:Warm-starting variable: Variable_2/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_2/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with Variable_2/Adam
# INFO:tensorflow:Warm-starting variable: Variable_2/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_2/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with Variable_2/Adam_1
# INFO:tensorflow:Warm-starting variable: Variable_4/Adam; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_4/Adam:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with Variable_4/Adam
# INFO:tensorflow:Warm-starting variable: Variable_4/Adam_1; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable Variable_4/Adam_1:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with Variable_4/Adam_1
# INFO:tensorflow:Warm-starting variable: beta1_power; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable beta1_power:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with beta1_power
# INFO:tensorflow:Warm-starting variable: beta2_power; prev_var_name: Unchanged
# INFO:tensorflow:Initialize variable beta2_power:0 from checkpoint /mnt/Data/tmp/resnet/plastic_56 with beta2_power
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /mnt/Data/tmp/resnet/plastic_56/mnist/model.ckpt.
# INFO:tensorflow:accuracy = 21.875
# INFO:tensorflow:loss = 2.5350008, step = 0
# INFO:tensorflow:global_step/sec: 10.2521
# INFO:tensorflow:accuracy = 25.0 (9.756 sec)
# INFO:tensorflow:loss = 2.2070682, step = 100 (9.756 sec)
# INFO:tensorflow:global_step/sec: 8.60286
# INFO:tensorflow:accuracy = 46.875 (11.625 sec)
# INFO:tensorflow:loss = 1.5148842, step = 200 (11.625 sec)
# INFO:tensorflow:global_step/sec: 8.56983
# INFO:tensorflow:accuracy = 62.5 (11.670 sec)
# INFO:tensorflow:loss = 1.1221924, step = 300 (11.670 sec)
# INFO:tensorflow:global_step/sec: 8.53702
# INFO:tensorflow:accuracy = 68.75 (11.712 sec)
# INFO:tensorflow:loss = 0.96750337, step = 400 (11.712 sec)
# INFO:tensorflow:global_step/sec: 8.3265
# INFO:tensorflow:accuracy = 71.875 (12.010 sec)
# INFO:tensorflow:loss = 0.74081564, step = 500 (12.011 sec)
# INFO:tensorflow:global_step/sec: 7.54328
# INFO:tensorflow:accuracy = 75.0 (13.256 sec)
# INFO:tensorflow:loss = 0.80605423, step = 600 (13.255 sec)
# INFO:tensorflow:global_step/sec: 7.09382
# INFO:tensorflow:accuracy = 81.25 (14.100 sec)
# INFO:tensorflow:loss = 0.6511929, step = 700 (14.100 sec)
# INFO:tensorflow:global_step/sec: 6.69198
# INFO:tensorflow:accuracy = 84.375 (14.940 sec)
# INFO:tensorflow:loss = 0.5460206, step = 800 (14.939 sec)
# INFO:tensorflow:global_step/sec: 6.55782
# INFO:tensorflow:accuracy = 78.125 (15.249 sec)
# INFO:tensorflow:loss = 0.6342248, step = 900 (15.249 sec)
# INFO:tensorflow:global_step/sec: 6.52954
# INFO:tensorflow:accuracy = 75.0 (15.315 sec)
# INFO:tensorflow:loss = 0.8496572, step = 1000 (15.315 sec)
# INFO:tensorflow:global_step/sec: 6.7616
# INFO:tensorflow:accuracy = 93.75 (14.790 sec)
# INFO:tensorflow:loss = 0.42684174, step = 1100 (14.790 sec)
# INFO:tensorflow:global_step/sec: 6.53664
# INFO:tensorflow:accuracy = 78.125 (15.298 sec)
# INFO:tensorflow:loss = 0.55120146, step = 1200 (15.298 sec)
# INFO:tensorflow:global_step/sec: 6.17582
# INFO:tensorflow:accuracy = 87.5 (16.192 sec)
# INFO:tensorflow:loss = 0.39835942, step = 1300 (16.192 sec)
# INFO:tensorflow:global_step/sec: 6.25724
# INFO:tensorflow:accuracy = 87.5 (15.982 sec)
# INFO:tensorflow:loss = 0.28687087, step = 1400 (15.981 sec)
# INFO:tensorflow:global_step/sec: 6.29814
# INFO:tensorflow:accuracy = 90.625 (15.878 sec)
# INFO:tensorflow:loss = 0.25580606, step = 1500 (15.878 sec)
# INFO:tensorflow:global_step/sec: 6.28538
# INFO:tensorflow:accuracy = 87.5 (15.910 sec)
# INFO:tensorflow:loss = 0.508487, step = 1600 (15.910 sec)
# INFO:tensorflow:global_step/sec: 6.12683
# INFO:tensorflow:accuracy = 78.125 (16.328 sec)
# INFO:tensorflow:loss = 0.5023478, step = 1700 (16.330 sec)
# INFO:tensorflow:Saving checkpoints for 1718 into /mnt/Data/tmp/resnet/plastic_56/mnist/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.29912412.

# %%
print(model.evaluate(input_fn=lambda:test_input_fn(mnist)))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-18-12:00:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /mnt/Data/tmp/resnet/plastic_56/mnist/model.ckpt-1718
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-06-18-12:01:07
# INFO:tensorflow:Saving dict for global step 1718: accuracy = 0.8895232, global_step = 1718, loss = 0.3564906
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1718: /mnt/Data/tmp/resnet/plastic_56/mnist/model.ckpt-1718
# {'accuracy': 0.8895232, 'loss': 0.3564906, 'global_step': 1718}
